# %%
import requests
import pandas as pd

# %%
# Auth

# openai.organization = "org-FDLaKQ4DsHmJstN7LGujAHHq"
# openai.api_key = "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"  # API_Key Christian
auth_header = {'Authorization': 'Bearer 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',
               'OpenAI-Organization': 'org-FDLaKQ4DsHmJstN7LGujAHHq'}
# r = requests.get('https://api.openai.com/v1/engines', headers=auth_header)
# r.json()

# %%
def gpt_request(engine_id, request_body):

    request = requests.post(f"https://api.openai.com/v1/engines/{engine_id}/completions",
                            json=request_body,
                            headers=auth_header)

    result = request.json()['choices'][0]['text'].lstrip('\n')

    return result

# %%
def classify_topic(input_text):

    prompt = 'What is the topic of the following text in one word:\n###\n' + input_text + '\n###\n'

    engine_id = 'davinci-instruct-beta-v3'

    request_body = {
        'prompt': prompt,
        "max_tokens": 20,
        "temperature": 0.3,
        "frequency_penalty": 1,
        "stop": '###'
    }

    return gpt_request(engine_id, request_body)

classify_topic('Jupiter is the fifth planet from the Sun and the largest in the Solar System. It is a gas giant with a mass one-thousandth that of the Sun, but two-and-a-half times that of all the other planets in the Solar System combined. Jupiter is one of the brightest objects visible to the naked eye in the night sky, and has been known to ancient civilizations since before recorded history. ')
# Out:
# 'Planet'

# %%
def classify_sentiment(input_text):

    prompt = 'Classify the sentiment of the following text with Positive, Negative or Neutral :\n###\n' + input_text + '\n###\n'

    engine_id = 'davinci-instruct-beta-v3'

    request_body = {
        'prompt': prompt,
        "max_tokens": 10,
        "temperature": 0,
        "frequency_penalty": 1,
        "stop": '###'
    }

    return gpt_request(engine_id, request_body)

classify_sentiment('Bitcoin hits new record as crypto market cap exceeds $3 tln - Reuters; Bitcoin and ether made record peaks in the Asia session on Tuesday as enthusiasm for cryptocurrency adoption and fears about inflation leant support to the asset class.')
# Out:
# 'Positive'

# %%
classify_sentiment('Crypto rally lifts ether to new record, bitcoin to near 3-week high - Reuters; Bitcoin rose to a two-and-a-half-week peak on Monday and ether climbed to a fresh record as cryptocurrencies ride higher on a wave of momentum, flows, favourable news and inflation fears.')
# Out:
# 'Positive'

# %%
classify_sentiment("Australia's banking regulator looks into CBA's jump into crypto - Reuters; Australia's banking watchdog said it was examining the regulatory implications of Commonwealth Bank's planned introduction of bitcoin trading to unsophisticated retail investors…")
# Out:
# 'The sentiment in the text is Neutral.'

# %%
news_df = pd.read_excel('../input_data.xlsx')
news_df['sentiment'] = ""
news_df
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              0             0
# 1              1             1
# 2              2             2
# 3              3             3
# 4              4             4
# ...          ...           ...
# 1885        1885           133
# 1886        1886           134
# 1887        1887           135
# 1888        1888           136
# 1889        1889           137
#
#                                                  author  \
# 0                                        Richard Lawler
# 1888  https://s.yimg.com/uu/api/res/1.2/hXU_4XMXUJ76... 2021-12-29 09:23:05
# 1889  https://thumbor.forbes.com/thumbor/fit-in/1200... 2021-12-28 12:39:01
#
#                                                 content  \
# 0     A similar hoax earlier this year tied Walmart ...
# 1     Ether.\r\nNurPhoto\r\n<ul><li>The approval of ...
# 2     Bitcoin was trading over 7% higher on Monday m...
# 3     A representation of the virtual cryptocurrency...
# 4     By Reuters Staff\r\nFILE PHOTO: A representati...
# ...                                                 ...
# 1885  Crypto has been many things in its short histo...
# 1886  What sectors of the crypto market should you c...
# 1887  Hi Market Wrap readers! During the final two w...
# 1888  Tokens of layer 1 blockchain Fantom (FTM) were...
# 1889  getty\r\ngetty\r\nA lot of people have made a ...
#
#                     source.id              source.name      Query  \
# 0                   the-verge                The Verge    bitcoin
# 1            business-insider         Business Insider    bitcoin
# 2                         NaN             Entrepreneur    bitcoin
# 3                     reuters                  Reuters    bitcoin
# 4                     reuters                  Reuters    bitcoin
# ...                       ...                      ...        ...
# 1885  the-wall-street-journal  The Wall Street Journal  ethereum2
# 1886                      NaN                   Forbes  ethereum2
# 1887                      NaN      Yahoo Entertainment  ethereum2
# 1888                      NaN      Yahoo Entertainment  ethereum2
# 1889                      NaN                   Forbes  ethereum2
#
#                                                   merge sentiment
# 0     A fake press release claiming Kroger accepts c...
# 1     An ethereum futures ETF will be available befo...
# 2     Bitcoin Trades 7% Higher; Bitcoin was trading ...
# 3     Bitcoin hits new record as crypto market cap e...
# 4     Bitcoin hits new record as crypto market cap e...
# ...                                                 ...       ...
# 1885  NFTs and SNL: Crypto Keeps Burrowing Into Main...
# 1886  Where To Put $1,000 In Your Cryptocurrency Por...
# 1887  Market Wrap Year-End Review: Altcoins, NFTs Fi...
# 1888  Fantom Surges as Investors Seach for Next Laye...
# 1889  3 Cryptos For 2022: Bitcoin, Matic And Compoun...
#
# [1890 rows x 14 columns]

# %%
news_df_sample = news_df.sample(frac=0.01)

# %%
def sentiment_loop(df):
    for rows, index in df.iterrows():
        df['sentiment'][rows] = classify_sentiment(df['merge'][rows])
    
    return df

# %%
news_df_sample_sentiment = sentiment_loop(news_df_sample)
# Out:
# C:\Users\CHRIST~1\AppData\Local\Temp/ipykernel_22176/2918625277.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentiment'][rows] = classify_sentiment(df['merge'][rows])

# %%
news_df_sample_sentiment
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 1066        1066           120
# 1416        1416            70
# 383          383           112
# 308          308            37
# 95            95            95
# 455          455            44
# 1011        1011            65
# 62            62            62
# 1424        1424            78
# 1617        1617           131
# 1243        1243            28
# 242          242           109
# 566          566            26
# 1592        1592           106
# 805          805           125
# 1292        1292            77
# 1411        1411            65
# 1377        1377            31
# 27            27            27
#
#                                                  author  \
# 1066              newsfeedback@fool.com (Sean Williams)
# 1416  Michael del Castillo, Forbes Staff, \n Michael...
# 1617  By Lambert Strether of Corrente.\r\nBird Song ...               NaN
# 1243  Robert Kiyosaki.The Rich Dad Channel/YouTube\r...  business-insider
# 242   <ul><li>The Navy Pier Flyover got an “award of...               NaN
# 566   Saturday afternoon, 91 geeks huddled around a ...               NaN
# 1592  The year 2021 was a big year for cryptocurrenc...               NaN
# 805   The final part of our end-of-year series focus...               NaN
# 1292  Last Friday, an announcement that was posted o...               NaN
# 1411  No asset class has been hotter since the coron...               NaN
# 1377  Happy Thursday! Welcome to Distributed Ledger,...               NaN
# 27    The West End Phoenix, a four-year-old communit...               NaN
#
#               source.name         Query  \
# 1066          Motley Fool     ethereum2
# 1416               Forbes  shibainucoin
# 383   Yahoo Entertainment     Chainlink
# 308                Forbes      ethereum
# 95                   CNBC        solana
# 455          The Guardian      dogecoin
# 1011          Motley Fool  shibainucoin
# 62            Motley Fool  shibainucoin
# 1424          Gizmodo.com  shibainucoin
# 1617  Nakedcapitalism.com     ethereum2
# 1243     Business Insider      ethereum
# 242       Streetsblog.org     Chainlink
# 566          Slashdot.org      ethereum
# 1592             Livemint     Chainlink
# 805        Springwise.com     ethereum2
# 1292    Notebookcheck.net  shibainucoin
# 1411          Motley Fool  shibainucoin
# 1377          MarketWatch      ethereum
# 27         The New Yorker      ethereum
#
#                                                   merge  \
# 1066  Could Shiba Inu Hit $1 in 2022?; Following a 6...
# 1416  Nine Videos That Defined Crypto In 2021; This ...
# 383   Where Does Cryptocurrency Come From?; It's fai...
# 308   Ethereum: The $640 Billion Dollar Question; As...
# 95    Solana is up 17,000% this year—here's what to ...
# 455   Cryptodragons’ den: what is Paul Pogba selling...
# 1011  You Could've Made $1 Million Investing Less Th...
# 62    Why Cryptocurrencies Avalanche and Fantom Jump...
# 1424  Crypto Prices Seemingly Jump by Billions of Do...
# 1617  2:00PM Water Cooler 12/21/2021; ~ Today's Wate...
# 1243  'Rich Dad Poor Dad' author Robert Kiyosaki exp...
# 242   Today’s Headlines for Friday, November 12; The...
# 566   27th Annual Text Adventure Competition Won By ...
# 1592  Five potentially game-changing crypto projects...
# 805   Eco-consumption; Below we explore the rise of ...
# 1292  More merchants support Shiba Inu payments as t...
# 1411  3 Cryptocurrencies That Can Crush Shiba Inu in...
# 1377  Distributed Ledger: Bitcoin is so 2021. Here’s...
# 27    Thanks for the Bitcoin! How Does It Work?; A q...
#
#                                     sentiment
# 1066                                  Neutral
# 1416                                 Positive
# 383                                  Positive
# 308                                  Positive
# 95                                   Positive
# 455                                  Negative
# 1011  The sentiment in this text is Positive.
# 62                                    Neutral
# 1424    The sentiment in the text is Neutral.
# 1617                                 Positive
# 1243    The sentiment in the text is Neutral.
# 242                                  Positive
# 566                                  Positive
# 1592                                 Positive
# 805                                  Positive
# 1292                                 Positive
# 1411                                 Positive
# 1377    The sentiment in the text is Neutral.
# 27                                   Positive
