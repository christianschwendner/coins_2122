# %%
import pandas as pd

# %%
from newsapi import NewsApiClient

# %%
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key='ff25f8ba048b4928b4db576d9a4f614b')

# /v2/top-headlines
top_headlines = newsapi.get_top_headlines(q='bitcoin', 
                                          language='en',
                                          from_param='2021-11-01',
                                          to='2021-11-30',
                                          sort_by='relevancy',
                                          page=1)


# /v2/everything
all_articles = newsapi.get_everything(q='bitcoin',
                                      from_param='2021-11-01',
                                      to='2021-11-29',
                                      language='en',
                                      sort_by='relevancy',
                                      page=1)

# /v2/top-headlines/sources
sources = newsapi.get_sources()

# %%
all_articles
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\CHRIST~1\AppData\Local\Temp/ipykernel_13384/2555399544.py in <module>
# ----> 1 all_articles
#
# NameError: name 'all_articles' is not defined

# %% [markdown]
# # Workflow for skript automation

# %%
from newsapi import NewsApiClient

# Init
newsapi = NewsApiClient(api_key='ff25f8ba048b4928b4db576d9a4f614b')

def news_fetcher(q="bitcoin", from_param='2021-11-05', to='2021-12-05'):
    # /v2/top-headlines
    articles = newsapi.get_everything(q=q, 
                                      language='en',
                                      from_param=from_param,
                                      to=to,
                                      sort_by='relevancy',
                                      page=1)
    return articles

# %%
articles_bitcoin = news_fetcher(q="bitcoin")
articles_ethereum = news_fetcher(q="ethereum")
articles_dogecoin = news_fetcher(q="dogecoin")
articles_shibainucoin = news_fetcher(q="shiba inu coin")
articles_solana = news_fetcher(q="solana")
articles_Chainlink = news_fetcher(q="Chainlink")
articles_ethereum2 = news_fetcher(q="ethereum 2")

# %%
articles_bitcoin_df = pd.json_normalize(articles_bitcoin['articles'])
articles_ethereum_df = pd.json_normalize(articles_ethereum['articles'])
articles_dogecoin_df = pd.json_normalize(articles_dogecoin['articles'])
articles_shibainucoin_df = pd.json_normalize(articles_shibainucoin['articles'])
articles_solana_df = pd.json_normalize(articles_solana['articles'])
articles_Chainlink_df = pd.json_normalize(articles_Chainlink['articles'])
articles_ethereum2_df = pd.json_normalize(articles_ethereum2['articles'])

# %%
articles_bitcoin_df['Query'] = "bitcoin"
articles_ethereum_df['Query'] = "ethereum"
articles_dogecoin_df['Query'] = "dogecoin"
articles_shibainucoin_df['Query'] = "shibainucoin"
articles_solana_df['Query'] = "solana"
articles_Chainlink_df['Query'] = "Chainlink"
articles_ethereum2_df['Query'] = "ethereum2"

# %%
articles_bitcoin_df.to_excel('output/articles_bitcoin.xlsx')
articles_ethereum_df.to_excel('output/articles_ethereum.xlsx')
articles_dogecoin_df.to_excel('output/articles_dogecoin.xlsx')
articles_shibainucoin_df.to_excel('output/articles_shibainucoin.xlsx')
articles_solana_df.to_excel('output/articles_solana.xlsx')
articles_Chainlink_df.to_excel('output/articles_Chainlink.xlsx')
articles_ethereum2_df.to_excel('output/articles_ethereum2.xlsx')

# %%
articles_list = [articles_bitcoin_df,
                articles_ethereum_df,
                articles_dogecoin_df,
                articles_shibainucoin_df,
                articles_solana_df,
                articles_Chainlink_df,
                articles_ethereum2_df]

# %%
df_dict = pd.DataFrame.concat(articles_list)
# articles_all_norm = pd.json_normalize(df_dict['articles'])
# articles_all_norm
df_dict
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\CHRIST~1\AppData\Local\Temp/ipykernel_14648/2159766093.py in <module>
# ----> 1 df_dict = pd.DataFrame.concat(articles_list)
#       2 # articles_all_norm = pd.json_normalize(df_dict['articles'])
#       3 # articles_all_norm
#       4 df_dict
#
# AttributeError: type object 'DataFrame' has no attribute 'concat'

# %%
articles_all = pd.concat(articles_list, axis=0, ignore_index=True)
articles_all.to_excel("output/20211205_articles_all.xlsx")

# %%
len(articles_all)
# Out:
# 140

# %% [markdown]
# # Google News

# %%
from GoogleNews import GoogleNews
#from newspaper import Article
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\CHRIST~1\AppData\Local\Temp/ipykernel_6844/3954946074.py in <module>
# ----> 1 from GoogleNews import GoogleNews
#       2 #from newspaper import Article
#
# ModuleNotFoundError: No module named 'GoogleNews'

# %%
googlenews.results(sort=True)
# Out:
# '<' not supported between instances of 'datetime.datetime' and 'float'
# [{'title': "What Happens to Bitcoin When It's No Longer the Biggest Cryptocurrency?",
#   'desc': 'bookmark_border',
#   'date': '7 days ago',
#   'datetime': datetime.datetime(2021, 11, 22, 21, 58, 53, 532329),
#   'link': 'news.google.com/./articles/CBMiOmh0dHBzOi8vbW9uZXkuY29tL2JpdGNvaW4tZXRoZXItZmxpcHBlbmluZy1sYXJnZXN0LWNyeXB0by_SAUNodHRwczovL21vbmV5LmNvbS9iaXRjb2luLWV0aGVyLWZsaXBwZW5pbmctbGFyZ2VzdC1jcnlwdG8vP2FtcD10cnVl?hl=en-US&gl=US&ceid=US%3Aen',
#   'img': 'https://lh3.googleusercontent.com/proxy/O53QCJE9AuUo4sKHbuDqgd8ElpsKIEpsHctYGNv62j3BHGZzIYKIvjrnzKYTFOKDWIQi9s6wB_mDgu_ny3wbsreIZln3U1OMDJkc7AumssV6EFA7nu9vDZnl2AnXdVTcc7fzpkYyMNphTdG-=s0-w100-h100-dcBZSOhzkG',
#   'media': None,
#   'site': 'MONEY'},
#  {'title': 'Who Sets the Rules of Bitcoin as Nation-States and Corps Roll In',
#   'desc': 'bookmark_border',
#   'date': '2 hours ago',
# ...

# %%
googlenews.get_texts()
# Out:
# ["What Happens to Bitcoin When It's No Longer the Biggest Cryptocurrency?",
#  'Who Sets the Rules of Bitcoin as Nation-States and Corps Roll In',
#  "Bitcoin Reached A 7-Week Low Today—Here's What Traders Should Know",
#  "El-Erian says he bought bitcoin but sold too early — here's when he'd feel comfortable buying again",
#  "'Omicron' the cryptocurrency rides new variant rollercoaster",
#  'Whales bought 40,000 Bitcoin during the dip this week',
#  'Crypto comeback: Bitcoin bounces back after brutal selloff',
#  'Bitcoin (BTC USD) Cryptocurrency Price Falls 20% From Peak; Ether ($ETH) Tumbles',
#  'Bitcoin price outlook: 2 reasons why rally stalled, weakness may last',
#  'Who is Satoshi Nakamoto? Two men claimed to be the inventor of Bitcoin',
#  'El Salvador Buys 100 More Bitcoins as Crypto Market Falls',
#  'The World Bitcoin Will Build',
#  'Buy the dip and these gifts for the crypto enthusiast in your life',
# ...

# %%
googlenews = GoogleNews(start='31/10/2021',end='28/11/2021')
googlenews.search('Ethereum')
result=googlenews.result()
df=pd.DataFrame(result)
df.head()
# Out:
# HTTP Error 429: Too Many Requests
# Empty DataFrame
# Columns: []
# Index: []

# %%
#googlenews.search()
for i in range(2,20):
    googlenews.getpage(i)
    result=googlenews.result()
    df=pd.DataFrame(result)
# Out:
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests

# %%
result_0 = googlenews.page_at(1)

desc_1 = googlenews.get_texts()
link_1 = googlenews.get_links()

for i in list(range(2, 70)):

    result = googlenews.page_at(i)
    desc = googlenews.get_texts()
    link = googlenews.get_links()

    desc_1 = desc_1 + desc
    link_1 = link_1 + link
# Out:
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\CHRIST~1\AppData\Local\Temp/ipykernel_21500/1282890680.py in <module>
#       6 for i in list(range(2, 70)):
#       7
# ----> 8     result = googlenews.page_at(i)
#       9     desc = googlenews.get_texts()
#      10     link = googlenews.get_links()
#
# ...

# %%
column_names = ["description_text", 'link']
df = pd.DataFrame(columns = column_names)

df['description_text'] = desc_1
df['link'] = link_1
display(df)

df.to_csv('google_news.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\CHRIST~1\AppData\Local\Temp/ipykernel_19912/1998203839.py in <module>
#       2 df = pd.DataFrame(columns = column_names)
#       3
# ----> 4 df['description_text'] = desc_1
#       5 df['link'] = link_1
#       6 display(df)
#
# NameError: name 'desc_1' is not defined

# %%
import requests

query = "selenium"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36'}
url = 'https://www.google.com?q=' + query
res = requests.get(url, headers=headers)
print(res)
# Out:
# <Response [200]>

# %% [markdown]
# # Medium template
# ### https://medium.com/analytics-vidhya/googlenews-api-live-news-from-google-news-using-python-b50272f0a8f0

# %%
from GoogleNews import GoogleNews
from newspaper import Article
from newspaper import Config
import pandas as pd
import nltk
#config will allow us to access the specified url for which we are 
#not authorized. Sometimes we may get 403 client error while parsing 
#the link to download the article.

nltk.download('punkt')

user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'
config = Config()
config.browser_user_agent = user_agent
googlenews=GoogleNews(start='10/24/2021',end='12/05/2021')
googlenews.search('Bitcoin')
result=googlenews.result()
df=pd.DataFrame(result)
print(df.head())

for i in range(2,20):
    googlenews.getpage(i)
    result=googlenews.result()
    df=pd.DataFrame(result)
list=[]

for ind in df.index:
    dict={}
    article = Article(df['link'][ind],config=config)
    article.download()
    article.parse()
    article.nlp()
    dict['Date']=df['date'][ind]
    dict['Media']=df['media'][ind]
    dict['Title']=article.title
    dict['Article']=article.text
    dict['Summary']=article.summary
    list.append(dict)
news_df=pd.DataFrame(list)
news_df.to_excel("articles.xlsx")

# %% [markdown]
# # Selfmade Function

# %%
from GoogleNews import GoogleNews
from newspaper import Article
from newspaper import Config
import pandas as pd
import nltk
import os

# %%
def article_fetch(key_word, start='10/24/2021', end='12/05/2021'):
    nltk.download('punkt')

    # Config
    user_agent = 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'
    config = Config()
    config.browser_user_agent = user_agent
    
    # Headers
    print("Fetch headers")
    googlenews=GoogleNews(start, end)
    googlenews.search(key_word)
    result=googlenews.result()
    df=pd.DataFrame(result)
    print(df.head())

    # Crawling
    print("Crawl results")
    for i in range(2,20):
        googlenews.getpage(i)
        result=googlenews.result()
        df=pd.DataFrame(result)
        sleep
    list=[]

#     # Articles
#     print("Fetch articles")
#     for ind in df.index:
#         dict={}
#         article = Article(df['link'][ind],config=config)
#         article.download()
#         article.parse()
#         article.nlp()
#         dict['Date']=df['date'][ind]
#         dict['Media']=df['media'][ind]
#         dict['Title']=article.title
#         dict['Article']=article.text
#         dict['Summary']=article.summary
#         list.append(dict)
        
    # Saving
    print("Saving Dataframe")
#    news_df=pd.DataFrame(list)
    df.to_excel("articles_" + key_word + ".xlsx")
    print("Job finished.")

# %%
article_fetch("Bitcoin")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Christian\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Fetch headers
# HTTP Error 429: Too Many Requests
# Empty DataFrame
# Columns: []
# Index: []
# Crawl results
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# HTTP Error 429: Too Many Requests
# Saving Dataframe
# Job finished.
