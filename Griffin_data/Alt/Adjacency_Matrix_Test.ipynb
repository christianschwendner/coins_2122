# %%
import tables
tables.test()
# Out:
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# PyTables version:    3.6.1
# HDF5 version:        1.12.1
# NumPy version:       1.21.4
# Numexpr version:     2.8.1 (not using Intel's VML/MKL)
# Zlib version:        1.2.11 (in Python interpreter)
# BZIP2 version:       1.0.8 (13-Jul-2019)
# Blosc version:       1.21.0 (2020-12-22)
# Blosc compressors:   blosclz (2.3.0), lz4 (1.9.3), lz4hc (1.9.3), zlib (1.2.8), zstd (1.4.8)
# Blosc filters:       shuffle, bitshuffle
# Python version:      3.8.12 | packaged by conda-forge | (default, Oct 12 2021, 21:22:46) [MSC v.1916 64 bit (AMD64)]
# Platform:            Windows-10-10.0.19044-SP0
# Byte-ordering:       little
# Detected cores:      8
# Default encoding:    utf-8
# Default FS encoding: utf-8
# Default locale:      (de_DE, cp1252)
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# Performing only a light (yet comprehensive) subset of the test suite.
# If you want a more complete test, try passing the --heavy flag to this script
# (or set the 'heavy' parameter in case you are using tables.test() call).
# The whole suite will take more than 4 hours to complete on a relatively
# modern CPU and around 512 MB of main memory.
# -=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=-=
# C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\filters.py:326: FiltersWarning: compression library ``lzo`` is not available; using ``zlib`` instead
#   warnings.warn("compression library ``%s`` is not available; "
# C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_array.py:519: FutureWarning: creating an array with a subarray dtype will behave differently when the `np.array()` (or `asarray`, etc.) call includes an array or array object.
# If you are converting a single array or a list of arrays,you can opt-in to the future behaviour using:
#     np.array(arr, dtype=np.dtype(['f', dtype]))['f']
#     np.array([arr1, arr2], dtype=np.dtype(['f', dtype]))['f']
#
# By including a new field and indexing it after the conversion.
# This may lead to a different result or to current failures succeeding.  (FutureWarning since NumPy 1.20)
#   tupleInt = numpy.array(numpy.arange((4)), dtype=(numpy.int_, (4,)))
# ..................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................s............................................ssss...................................................ss.....................................................................................................sssss....F......................................C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\flavor.py:395: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   nparr = numpy.array(array)
# ..........................................................................................................................................................................................................................................................................................................................................................................................................................................ssssssssssssssssssssssssssss........................................................ssssssssssssssssssssssssssssssssssssssssssssssssssssssss...............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ssssss..........................................................................................................................................................................................................................................................................................C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\leaf.py:544: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   key = numpy.array(key)
# .........................................................................................................................................................sssssss........................................................ssssssssssssss...................................................................................................................................................................................................ssssssssss............................................................sssss..........ssssssssss.................................................................ssssssssss..........ssssssssss...............................................................................................................................................................ssssss............ssssss.................................................................................................................................EEEEEEEEEEEE..................................................................s................................................................................................................................................................................................................................................................................................s...s........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ssssssssssssssssssss.....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
# ======================================================================
# ERROR: test00_attributes (tables.tests.test_vlarray.Fletcher32TestCase)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 37, in setUp
#     self.populateFile()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 47, in populateFile
#     vlarray = self.h5file.create_vlarray(group, 'vlarray1',
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\file.py", line 1493, in create_vlarray
#     ptobj = VLArray(parentnode, name,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 349, in __init__
#     super(VLArray, self).__init__(parentnode, name, new, filters,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\leaf.py", line 286, in __init__
#     super(Leaf, self).__init__(parentnode, name, _log)
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\node.py", line 264, in __init__
#     self._v_objectid = self._g_create()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 419, in _g_create
#     self._v_objectid = self._create_array(self._v_new_title)
#   File "tables\hdf5extension.pyx", line 1968, in tables.hdf5extension.VLArray._create_array
# tables.exceptions.HDF5ExtError: HDF5 error back trace
#
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5D.c", line 141, in H5Dcreate2
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1806, in H5VL_dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1771, in H5VL__dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLnative_dataset.c", line 73, in H5VL__native_dataset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 396, in H5D__create_named
#     unable to create and link to dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1767, in H5L_link_object
#     unable to create new link to object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 2009, in H5L__create_real
#     can't insert link
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 837, in H5G_traverse
#     internal path traversal failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 613, in H5G__traverse_real
#     traversal operator failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1815, in H5L__link_cb
#     unable to create object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Oint.c", line 2468, in H5O_obj_create
#     unable to open object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Doh.c", line 289, in H5O__dset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 1282, in H5D__create
#     H5Z_has_optional_filter() failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Z.c", line 1044, in H5Z_ignore_filters
#     not suitable for filters
#
# End of HDF5 error back trace
#
# Problems creating the VLArray.
#
# ======================================================================
# ERROR: test01_read (tables.tests.test_vlarray.Fletcher32TestCase)
# Checking vlarray read.
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 37, in setUp
#     self.populateFile()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 47, in populateFile
#     vlarray = self.h5file.create_vlarray(group, 'vlarray1',
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\file.py", line 1493, in create_vlarray
#     ptobj = VLArray(parentnode, name,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 349, in __init__
#     super(VLArray, self).__init__(parentnode, name, new, filters,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\leaf.py", line 286, in __init__
#     super(Leaf, self).__init__(parentnode, name, _log)
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\node.py", line 264, in __init__
#     self._v_objectid = self._g_create()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 419, in _g_create
#     self._v_objectid = self._create_array(self._v_new_title)
#   File "tables\hdf5extension.pyx", line 1968, in tables.hdf5extension.VLArray._create_array
# tables.exceptions.HDF5ExtError: HDF5 error back trace
#
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5D.c", line 141, in H5Dcreate2
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1806, in H5VL_dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1771, in H5VL__dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLnative_dataset.c", line 73, in H5VL__native_dataset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 396, in H5D__create_named
#     unable to create and link to dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1767, in H5L_link_object
#     unable to create new link to object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 2009, in H5L__create_real
#     can't insert link
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 837, in H5G_traverse
#     internal path traversal failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 613, in H5G__traverse_real
#     traversal operator failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1815, in H5L__link_cb
#     unable to create object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Oint.c", line 2468, in H5O_obj_create
#     unable to open object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Doh.c", line 289, in H5O__dset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 1282, in H5D__create
#     H5Z_has_optional_filter() failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Z.c", line 1044, in H5Z_ignore_filters
#     not suitable for filters
#
# End of HDF5 error back trace
#
# Problems creating the VLArray.
#
# ======================================================================
# ERROR: test02a_getitem (tables.tests.test_vlarray.Fletcher32TestCase)
# Checking vlarray __getitem__ (slices)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 37, in setUp
#     self.populateFile()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 47, in populateFile
#     vlarray = self.h5file.create_vlarray(group, 'vlarray1',
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\file.py", line 1493, in create_vlarray
#     ptobj = VLArray(parentnode, name,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 349, in __init__
#     super(VLArray, self).__init__(parentnode, name, new, filters,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\leaf.py", line 286, in __init__
#     super(Leaf, self).__init__(parentnode, name, _log)
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\node.py", line 264, in __init__
#     self._v_objectid = self._g_create()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 419, in _g_create
#     self._v_objectid = self._create_array(self._v_new_title)
#   File "tables\hdf5extension.pyx", line 1968, in tables.hdf5extension.VLArray._create_array
# tables.exceptions.HDF5ExtError: HDF5 error back trace
#
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5D.c", line 141, in H5Dcreate2
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1806, in H5VL_dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1771, in H5VL__dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLnative_dataset.c", line 73, in H5VL__native_dataset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 396, in H5D__create_named
#     unable to create and link to dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1767, in H5L_link_object
#     unable to create new link to object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 2009, in H5L__create_real
#     can't insert link
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 837, in H5G_traverse
#     internal path traversal failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 613, in H5G__traverse_real
#     traversal operator failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1815, in H5L__link_cb
#     unable to create object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Oint.c", line 2468, in H5O_obj_create
#     unable to open object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Doh.c", line 289, in H5O__dset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 1282, in H5D__create
#     H5Z_has_optional_filter() failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Z.c", line 1044, in H5Z_ignore_filters
#     not suitable for filters
#
# End of HDF5 error back trace
#
# Problems creating the VLArray.
#
# ======================================================================
# ERROR: test02b_getitem (tables.tests.test_vlarray.Fletcher32TestCase)
# Checking vlarray __getitem__ (scalars)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 37, in setUp
#     self.populateFile()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 47, in populateFile
#     vlarray = self.h5file.create_vlarray(group, 'vlarray1',
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\file.py", line 1493, in create_vlarray
#     ptobj = VLArray(parentnode, name,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 349, in __init__
#     super(VLArray, self).__init__(parentnode, name, new, filters,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\leaf.py", line 286, in __init__
#     super(Leaf, self).__init__(parentnode, name, _log)
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\node.py", line 264, in __init__
#     self._v_objectid = self._g_create()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 419, in _g_create
#     self._v_objectid = self._create_array(self._v_new_title)
#   File "tables\hdf5extension.pyx", line 1968, in tables.hdf5extension.VLArray._create_array
# tables.exceptions.HDF5ExtError: HDF5 error back trace
#
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5D.c", line 141, in H5Dcreate2
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1806, in H5VL_dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1771, in H5VL__dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLnative_dataset.c", line 73, in H5VL__native_dataset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 396, in H5D__create_named
#     unable to create and link to dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1767, in H5L_link_object
#     unable to create new link to object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 2009, in H5L__create_real
#     can't insert link
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 837, in H5G_traverse
#     internal path traversal failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 613, in H5G__traverse_real
#     traversal operator failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1815, in H5L__link_cb
#     unable to create object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Oint.c", line 2468, in H5O_obj_create
#     unable to open object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Doh.c", line 289, in H5O__dset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 1282, in H5D__create
#     H5Z_has_optional_filter() failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Z.c", line 1044, in H5Z_ignore_filters
#     not suitable for filters
#
# End of HDF5 error back trace
#
# Problems creating the VLArray.
#
# ======================================================================
# ERROR: test03_append (tables.tests.test_vlarray.Fletcher32TestCase)
# Checking vlarray append.
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 37, in setUp
#     self.populateFile()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 47, in populateFile
#     vlarray = self.h5file.create_vlarray(group, 'vlarray1',
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\file.py", line 1493, in create_vlarray
#     ptobj = VLArray(parentnode, name,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 349, in __init__
#     super(VLArray, self).__init__(parentnode, name, new, filters,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\leaf.py", line 286, in __init__
#     super(Leaf, self).__init__(parentnode, name, _log)
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\node.py", line 264, in __init__
#     self._v_objectid = self._g_create()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 419, in _g_create
#     self._v_objectid = self._create_array(self._v_new_title)
#   File "tables\hdf5extension.pyx", line 1968, in tables.hdf5extension.VLArray._create_array
# tables.exceptions.HDF5ExtError: HDF5 error back trace
#
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5D.c", line 141, in H5Dcreate2
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1806, in H5VL_dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1771, in H5VL__dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLnative_dataset.c", line 73, in H5VL__native_dataset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 396, in H5D__create_named
#     unable to create and link to dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1767, in H5L_link_object
#     unable to create new link to object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 2009, in H5L__create_real
#     can't insert link
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 837, in H5G_traverse
#     internal path traversal failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 613, in H5G__traverse_real
#     traversal operator failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1815, in H5L__link_cb
#     unable to create object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Oint.c", line 2468, in H5O_obj_create
#     unable to open object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Doh.c", line 289, in H5O__dset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 1282, in H5D__create
#     H5Z_has_optional_filter() failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Z.c", line 1044, in H5Z_ignore_filters
#     not suitable for filters
#
# End of HDF5 error back trace
#
# Problems creating the VLArray.
#
# ======================================================================
# ERROR: test04_get_row_size (tables.tests.test_vlarray.Fletcher32TestCase)
# Checking get_row_size method.
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 37, in setUp
#     self.populateFile()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 47, in populateFile
#     vlarray = self.h5file.create_vlarray(group, 'vlarray1',
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\file.py", line 1493, in create_vlarray
#     ptobj = VLArray(parentnode, name,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 349, in __init__
#     super(VLArray, self).__init__(parentnode, name, new, filters,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\leaf.py", line 286, in __init__
#     super(Leaf, self).__init__(parentnode, name, _log)
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\node.py", line 264, in __init__
#     self._v_objectid = self._g_create()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 419, in _g_create
#     self._v_objectid = self._create_array(self._v_new_title)
#   File "tables\hdf5extension.pyx", line 1968, in tables.hdf5extension.VLArray._create_array
# tables.exceptions.HDF5ExtError: HDF5 error back trace
#
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5D.c", line 141, in H5Dcreate2
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1806, in H5VL_dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1771, in H5VL__dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLnative_dataset.c", line 73, in H5VL__native_dataset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 396, in H5D__create_named
#     unable to create and link to dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1767, in H5L_link_object
#     unable to create new link to object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 2009, in H5L__create_real
#     can't insert link
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 837, in H5G_traverse
#     internal path traversal failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 613, in H5G__traverse_real
#     traversal operator failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1815, in H5L__link_cb
#     unable to create object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Oint.c", line 2468, in H5O_obj_create
#     unable to open object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Doh.c", line 289, in H5O__dset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 1282, in H5D__create
#     H5Z_has_optional_filter() failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Z.c", line 1044, in H5Z_ignore_filters
#     not suitable for filters
#
# End of HDF5 error back trace
#
# Problems creating the VLArray.
#
# ======================================================================
# ERROR: test00_attributes (tables.tests.test_vlarray.AllFiltersTestCase)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 37, in setUp
#     self.populateFile()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 47, in populateFile
#     vlarray = self.h5file.create_vlarray(group, 'vlarray1',
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\file.py", line 1493, in create_vlarray
#     ptobj = VLArray(parentnode, name,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 349, in __init__
#     super(VLArray, self).__init__(parentnode, name, new, filters,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\leaf.py", line 286, in __init__
#     super(Leaf, self).__init__(parentnode, name, _log)
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\node.py", line 264, in __init__
#     self._v_objectid = self._g_create()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 419, in _g_create
#     self._v_objectid = self._create_array(self._v_new_title)
#   File "tables\hdf5extension.pyx", line 1968, in tables.hdf5extension.VLArray._create_array
# tables.exceptions.HDF5ExtError: HDF5 error back trace
#
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5D.c", line 141, in H5Dcreate2
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1806, in H5VL_dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1771, in H5VL__dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLnative_dataset.c", line 73, in H5VL__native_dataset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 396, in H5D__create_named
#     unable to create and link to dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1767, in H5L_link_object
#     unable to create new link to object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 2009, in H5L__create_real
#     can't insert link
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 837, in H5G_traverse
#     internal path traversal failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 613, in H5G__traverse_real
#     traversal operator failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1815, in H5L__link_cb
#     unable to create object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Oint.c", line 2468, in H5O_obj_create
#     unable to open object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Doh.c", line 289, in H5O__dset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 1282, in H5D__create
#     H5Z_has_optional_filter() failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Z.c", line 1044, in H5Z_ignore_filters
#     not suitable for filters
#
# End of HDF5 error back trace
#
# Problems creating the VLArray.
#
# ======================================================================
# ERROR: test01_read (tables.tests.test_vlarray.AllFiltersTestCase)
# Checking vlarray read.
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 37, in setUp
#     self.populateFile()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 47, in populateFile
#     vlarray = self.h5file.create_vlarray(group, 'vlarray1',
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\file.py", line 1493, in create_vlarray
#     ptobj = VLArray(parentnode, name,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 349, in __init__
#     super(VLArray, self).__init__(parentnode, name, new, filters,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\leaf.py", line 286, in __init__
#     super(Leaf, self).__init__(parentnode, name, _log)
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\node.py", line 264, in __init__
#     self._v_objectid = self._g_create()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 419, in _g_create
#     self._v_objectid = self._create_array(self._v_new_title)
#   File "tables\hdf5extension.pyx", line 1968, in tables.hdf5extension.VLArray._create_array
# tables.exceptions.HDF5ExtError: HDF5 error back trace
#
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5D.c", line 141, in H5Dcreate2
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1806, in H5VL_dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1771, in H5VL__dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLnative_dataset.c", line 73, in H5VL__native_dataset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 396, in H5D__create_named
#     unable to create and link to dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1767, in H5L_link_object
#     unable to create new link to object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 2009, in H5L__create_real
#     can't insert link
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 837, in H5G_traverse
#     internal path traversal failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 613, in H5G__traverse_real
#     traversal operator failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1815, in H5L__link_cb
#     unable to create object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Oint.c", line 2468, in H5O_obj_create
#     unable to open object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Doh.c", line 289, in H5O__dset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 1282, in H5D__create
#     H5Z_has_optional_filter() failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Z.c", line 1044, in H5Z_ignore_filters
#     not suitable for filters
#
# End of HDF5 error back trace
#
# Problems creating the VLArray.
#
# ======================================================================
# ERROR: test02a_getitem (tables.tests.test_vlarray.AllFiltersTestCase)
# Checking vlarray __getitem__ (slices)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 37, in setUp
#     self.populateFile()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 47, in populateFile
#     vlarray = self.h5file.create_vlarray(group, 'vlarray1',
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\file.py", line 1493, in create_vlarray
#     ptobj = VLArray(parentnode, name,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 349, in __init__
#     super(VLArray, self).__init__(parentnode, name, new, filters,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\leaf.py", line 286, in __init__
#     super(Leaf, self).__init__(parentnode, name, _log)
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\node.py", line 264, in __init__
#     self._v_objectid = self._g_create()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 419, in _g_create
#     self._v_objectid = self._create_array(self._v_new_title)
#   File "tables\hdf5extension.pyx", line 1968, in tables.hdf5extension.VLArray._create_array
# tables.exceptions.HDF5ExtError: HDF5 error back trace
#
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5D.c", line 141, in H5Dcreate2
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1806, in H5VL_dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1771, in H5VL__dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLnative_dataset.c", line 73, in H5VL__native_dataset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 396, in H5D__create_named
#     unable to create and link to dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1767, in H5L_link_object
#     unable to create new link to object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 2009, in H5L__create_real
#     can't insert link
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 837, in H5G_traverse
#     internal path traversal failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 613, in H5G__traverse_real
#     traversal operator failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1815, in H5L__link_cb
#     unable to create object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Oint.c", line 2468, in H5O_obj_create
#     unable to open object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Doh.c", line 289, in H5O__dset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 1282, in H5D__create
#     H5Z_has_optional_filter() failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Z.c", line 1044, in H5Z_ignore_filters
#     not suitable for filters
#
# End of HDF5 error back trace
#
# Problems creating the VLArray.
#
# ======================================================================
# ERROR: test02b_getitem (tables.tests.test_vlarray.AllFiltersTestCase)
# Checking vlarray __getitem__ (scalars)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 37, in setUp
#     self.populateFile()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 47, in populateFile
#     vlarray = self.h5file.create_vlarray(group, 'vlarray1',
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\file.py", line 1493, in create_vlarray
#     ptobj = VLArray(parentnode, name,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 349, in __init__
#     super(VLArray, self).__init__(parentnode, name, new, filters,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\leaf.py", line 286, in __init__
#     super(Leaf, self).__init__(parentnode, name, _log)
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\node.py", line 264, in __init__
#     self._v_objectid = self._g_create()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 419, in _g_create
#     self._v_objectid = self._create_array(self._v_new_title)
#   File "tables\hdf5extension.pyx", line 1968, in tables.hdf5extension.VLArray._create_array
# tables.exceptions.HDF5ExtError: HDF5 error back trace
#
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5D.c", line 141, in H5Dcreate2
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1806, in H5VL_dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1771, in H5VL__dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLnative_dataset.c", line 73, in H5VL__native_dataset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 396, in H5D__create_named
#     unable to create and link to dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1767, in H5L_link_object
#     unable to create new link to object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 2009, in H5L__create_real
#     can't insert link
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 837, in H5G_traverse
#     internal path traversal failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 613, in H5G__traverse_real
#     traversal operator failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1815, in H5L__link_cb
#     unable to create object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Oint.c", line 2468, in H5O_obj_create
#     unable to open object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Doh.c", line 289, in H5O__dset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 1282, in H5D__create
#     H5Z_has_optional_filter() failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Z.c", line 1044, in H5Z_ignore_filters
#     not suitable for filters
#
# End of HDF5 error back trace
#
# Problems creating the VLArray.
#
# ======================================================================
# ERROR: test03_append (tables.tests.test_vlarray.AllFiltersTestCase)
# Checking vlarray append.
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 37, in setUp
#     self.populateFile()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 47, in populateFile
#     vlarray = self.h5file.create_vlarray(group, 'vlarray1',
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\file.py", line 1493, in create_vlarray
#     ptobj = VLArray(parentnode, name,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 349, in __init__
#     super(VLArray, self).__init__(parentnode, name, new, filters,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\leaf.py", line 286, in __init__
#     super(Leaf, self).__init__(parentnode, name, _log)
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\node.py", line 264, in __init__
#     self._v_objectid = self._g_create()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 419, in _g_create
#     self._v_objectid = self._create_array(self._v_new_title)
#   File "tables\hdf5extension.pyx", line 1968, in tables.hdf5extension.VLArray._create_array
# tables.exceptions.HDF5ExtError: HDF5 error back trace
#
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5D.c", line 141, in H5Dcreate2
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1806, in H5VL_dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1771, in H5VL__dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLnative_dataset.c", line 73, in H5VL__native_dataset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 396, in H5D__create_named
#     unable to create and link to dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1767, in H5L_link_object
#     unable to create new link to object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 2009, in H5L__create_real
#     can't insert link
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 837, in H5G_traverse
#     internal path traversal failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 613, in H5G__traverse_real
#     traversal operator failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1815, in H5L__link_cb
#     unable to create object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Oint.c", line 2468, in H5O_obj_create
#     unable to open object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Doh.c", line 289, in H5O__dset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 1282, in H5D__create
#     H5Z_has_optional_filter() failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Z.c", line 1044, in H5Z_ignore_filters
#     not suitable for filters
#
# End of HDF5 error back trace
#
# Problems creating the VLArray.
#
# ======================================================================
# ERROR: test04_get_row_size (tables.tests.test_vlarray.AllFiltersTestCase)
# Checking get_row_size method.
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 37, in setUp
#     self.populateFile()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\tests\test_vlarray.py", line 47, in populateFile
#     vlarray = self.h5file.create_vlarray(group, 'vlarray1',
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\file.py", line 1493, in create_vlarray
#     ptobj = VLArray(parentnode, name,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 349, in __init__
#     super(VLArray, self).__init__(parentnode, name, new, filters,
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\leaf.py", line 286, in __init__
#     super(Leaf, self).__init__(parentnode, name, _log)
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\node.py", line 264, in __init__
#     self._v_objectid = self._g_create()
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\vlarray.py", line 419, in _g_create
#     self._v_objectid = self._create_array(self._v_new_title)
#   File "tables\hdf5extension.pyx", line 1968, in tables.hdf5extension.VLArray._create_array
# tables.exceptions.HDF5ExtError: HDF5 error back trace
#
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5D.c", line 141, in H5Dcreate2
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1806, in H5VL_dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLcallback.c", line 1771, in H5VL__dataset_create
#     dataset create failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5VLnative_dataset.c", line 73, in H5VL__native_dataset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 396, in H5D__create_named
#     unable to create and link to dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1767, in H5L_link_object
#     unable to create new link to object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 2009, in H5L__create_real
#     can't insert link
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 837, in H5G_traverse
#     internal path traversal failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Gtraverse.c", line 613, in H5G__traverse_real
#     traversal operator failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5L.c", line 1815, in H5L__link_cb
#     unable to create object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Oint.c", line 2468, in H5O_obj_create
#     unable to open object
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Doh.c", line 289, in H5O__dset_create
#     unable to create dataset
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Dint.c", line 1282, in H5D__create
#     H5Z_has_optional_filter() failed
#   File "D:\bld\hdf5_split_1638790631866\work\src\H5Z.c", line 1044, in H5Z_ignore_filters
#     not suitable for filters
#
# End of HDF5 error back trace
#
# Problems creating the VLArray.
#
# ======================================================================
# FAIL: from_sctype (tables.atom.Atom)
# Doctest: tables.atom.Atom.from_sctype
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\doctest.py", line 2204, in runTest
#     raise self.failureException(self.format_failure(new.getvalue()))
# AssertionError: Failed doctest test for tables.atom.Atom.from_sctype
#   File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\atom.py", line 326, in from_sctype
#
# ----------------------------------------------------------------------
# File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\atom.py", line 341, in tables.atom.Atom.from_sctype
# Failed example:
#     Atom.from_sctype('Float64')
# Exception raised:
#     Traceback (most recent call last):
#       File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\doctest.py", line 1336, in __run
#         exec(compile(example.source, filename, "single",
#       File "<doctest tables.atom.Atom.from_sctype[3]>", line 1, in <module>
#         Atom.from_sctype('Float64')
#       File "C:\Users\Christian\Documents\coding\anaconda3\envs\coins\lib\site-packages\tables\atom.py", line 348, in from_sctype
#         raise ValueError("unknown NumPy scalar type: %r" % (sctype,))
#     ValueError: unknown NumPy scalar type: 'Float64'
#
#
# ----------------------------------------------------------------------
# Ran 6358 tests in 419.356s
#
# FAILED (failures=1, errors=12, skipped=203)
# 1

# %%
from scipy.sparse import csr_matrix, rand
import tables as tb

a = rand(100000,100000, format='csr') #imagine that many values are stored in this matrix and that sparsity is low
b = a.T
l, m, n = a.shape[0], a.shape[1], b.shape[1]
 
f = tb.open_file('dot.h5', 'w')
filters = tb.Filters(complevel=5, complib='blosc')
out = f.create_carray(f.root, 'data', tb.Float32Atom(), shape=(l, n), filters=filters)
 
bl = 1000 #this is the number of rows we calculate each loop
#this may not the most efficient value
#look into buffersize usage in PyTables and adopt the buffersite of the
#carray accordingly to improve specifically fetching performance
 
b = b.tocsc() #we slice b on columns, csc improves performance
 
#this can also be changed to slice on rows instead of columns
for i in range(0, l, bl):
  out[:,i:min(i+bl, l)] = (a.dot(b[:,i:min(i+bl, l)])).toarray()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# C:\Users\CHRIST~1\AppData\Local\Temp/ipykernel_13000/3545416677.py in <module>
#       2 import tables as tb
#       3
# ----> 4 a = rand(100000,100000, format='csr') #imagine that many values are stored in this matrix and that sparsity is low
#       5 b = a.T
#       6 l, m, n = a.shape[0], a.shape[1], b.shape[1]
#
# ~\Documents\coding\anaconda3\envs\coins\lib\site-packages\scipy\sparse\construct.py in rand(m, n, density, format, dtype, random_state)
#     866
#     867     """
# --> 868     return random(m, n, density, format, dtype, random_state)
#
# ~\Documents\coding\anaconda3\envs\coins\lib\site-packages\scipy\sparse\construct.py in random(m, n, density, format, dtype, random_state, data_rvs)
#     806             data_rvs = partial(random_state.uniform, 0., 1.)
#     807
# --> 808     ind = random_state.choice(mn, size=k, replace=False)
#     809
#     810     j = np.floor(ind * 1. / m).astype(tp, copy=False)
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# mtrand.pyx in numpy.random.mtrand.RandomState.permutation()
#
# MemoryError: Unable to allocate 74.5 GiB for an array with shape (10000000000,) and data type int64

# %%
f
# Out:
# <closed File>

# %%
f.close()

# %%
from tables import *

h5file = open_file("tutorial1.h5", mode="w", title="Test file")

h5file
# Out:
# File(filename=tutorial1.h5, title='Test file', mode='w', root_uep='/', filters=Filters(complevel=0, shuffle=False, bitshuffle=False, fletcher32=False, least_significant_digit=None))
# / (RootGroup) 'Test file'
