# %%
import pandas as pd

# %%
user_to_user_time_series_C0_C1_C2 = pd.read_csv('KeyWords_New/user_to_user_time_series_C0_C1_C2.csv')
user_to_user_time_series_C3_C4 = pd.read_csv('KeyWords_New/user_to_user_time_series_C3_C4.csv')
user_to_user_time_series_C5_C6_C9 = pd.read_csv('KeyWords_New/user_to_user_time_series_C5_C6_C9.csv')

# %%
user_to_user_time_series_C0_C1_C2
# Out:
#                    dst              src  messages_sent  messages_received  \
# 0           a7madness1       a7madness1              1                  1
# 1             jrbrodin     aasianbokep2              0                  1
# 2       mauri_0fficial              aew              0                  1
# 3         declanjoyce9  aimingtoplease1              0                  2
# 4         akiramakkuro     akiramakkuro              1                  1
# ...                ...              ...            ...                ...
# 152064       zerokdefi        zerokdefi              1                  1
# 152065  julienrieutort   julienrieutort              1                  1
# 152066     societygurs      societygurs              1                  1
# 152067   trading_peter    trading_peter              1                  1
# 152068        mumetrdr         mumetrdr              1                  1
#
#         messages_total  contribution_index          start_time_  \
# ...

# %%
user_to_user_time_series_C3_C4
# Out:
#                     dst              src  messages_sent  messages_received  \
# 0       2u6ouraiigvilac  2u6ouraiigvilac              1                  1
# 1       _akutagawa_crow  _akutagawa_crow              1                  1
# 2             _army_mys        _army_mys              1                  1
# 3            _just_sae_       _just_sae_              1                  1
# 4                _musky           _musky              1                  1
# ...                 ...              ...            ...                ...
# 115090  getbrendanjames   cryptochicken7              0                  1
# 115091      casusbellii      casusbellii              1                  1
# 115092   nintendofrance   nintendofrance              1                  1
# 115093        kthtaexzx        kthtaexzx              1                  1
# 115094           15socl           15socl              1                  1
#
#         messages_total  contribution_index          start_time_  \
# ...

# %%
user_to_user_time_series_C5_C6_C9
# Out:
#                     dst              src  messages_sent  messages_received  \
# 0       5000spacealien1  5000spacealien1              4                  4
# 1         ricardomdias1  5000spacealien1              0                  1
# 2       _akutagawa_crow  _akutagawa_crow              1                  1
# 3            complexcon  a2stateoftheart              1                  0
# 4              a_osumuo         a_osumuo              1                  1
# ...                 ...              ...            ...                ...
# 123393   nintendofrance   nintendofrance              1                  1
# 123394        kthtaexzx        kthtaexzx              1                  1
# 123395           15socl           15socl              1                  1
# 123396     joao__parker     joao__parker              1                  1
# 123397   julienrieutort   julienrieutort              1                  1
#
# ...
