# %%
import pandas as pd

# %%
user_to_user_time_series_C0 = pd.read_csv('KeyWords_Final/user_to_user_time_series_C0.csv').drop_duplicates()
user_to_user_time_series_C1 = pd.read_csv('KeyWords_Final/user_to_user_time_series_C1.csv').drop_duplicates()
user_to_user_time_series_C2 = pd.read_csv('KeyWords_Final/user_to_user_time_series_C2.csv').drop_duplicates()
user_to_user_time_series_C3 = pd.read_csv('KeyWords_Final/user_to_user_time_series_C3.csv').drop_duplicates()
user_to_user_time_series_C4 = pd.read_csv('KeyWords_Final/user_to_user_time_series_C4.csv').drop_duplicates()
user_to_user_time_series_C5 = pd.read_csv('KeyWords_Final/user_to_user_time_series_C5.csv').drop_duplicates()
user_to_user_time_series_C6 = pd.read_csv('KeyWords_Final/user_to_user_time_series_C6.csv').drop_duplicates()
user_to_user_time_series_C7 = pd.read_csv('KeyWords_Final/user_to_user_time_series_C7.csv').drop_duplicates()
user_to_user_time_series_C8 = pd.read_csv('KeyWords_Final/user_to_user_time_series_C8.csv').drop_duplicates()
user_to_user_time_series_C9 = pd.read_csv('KeyWords_Final/user_to_user_time_series_C9.csv').drop_duplicates()

# %%
user_to_user_time_series_C0['cluster'] = 'C0'
user_to_user_time_series_C1['cluster'] = 'C1'
user_to_user_time_series_C2['cluster'] = 'C2'
user_to_user_time_series_C3['cluster'] = 'C3'
user_to_user_time_series_C4['cluster'] = 'C4'
user_to_user_time_series_C5['cluster'] = 'C5'
user_to_user_time_series_C6['cluster'] = 'C6'
user_to_user_time_series_C7['cluster'] = 'C7'
user_to_user_time_series_C8['cluster'] = 'C8'
user_to_user_time_series_C9['cluster'] = 'C9'

# %%
user_to_user_list = [user_to_user_time_series_C1, user_to_user_time_series_C2, user_to_user_time_series_C3,
                     user_to_user_time_series_C4, user_to_user_time_series_C5, user_to_user_time_series_C6,
                     user_to_user_time_series_C7, user_to_user_time_series_C8, user_to_user_time_series_C9]

# %%
user_to_user_time_series = user_to_user_time_series_C0.append(user_to_user_list, ignore_index=True)
user_to_user_time_series.drop_duplicates(inplace=True)
user_to_user_time_series
# Out:
#                    dst              src  messages_sent  messages_received  \
# 0         akiramakkuro     akiramakkuro              1                  1
# 1           aminulrubi       aminulrubi              1                  1
# 2          ammy_sahani      ammy_sahani              1                  1
# 3        thakur_shubbu  arunkum74386518              1                  0
# 4           brasilnets     basquetetv19              1                  0
# ...                ...              ...            ...                ...
# 554976       isakose25        isakose25              1                  1
# 554977     farmingsats      farmingsats              1                  1
# 554978      ponce54958       ponce54958              1                  1
# 554979  nintendofrance   nintendofrance              1                  1
# 554980       kthtaexzx        kthtaexzx              1                  1
#
#         messages_total  contribution_index  sentiment_avg  emotionality_avg  \
# ...

# %%
user_to_user_time_series.to_csv('KeyWords_New/user_to_user_time_series_All.csv')
