# %%
import pandas as pd

# %%
user_to_user_time_series_C0_C1_C2 = pd.read_csv('KeyWords_New/user_to_user_time_series_C0_C1_C2.csv')
user_to_user_time_series_C3_C4 = pd.read_csv('KeyWords_New/user_to_user_time_series_C3_C4.csv')
user_to_user_time_series_C5_C6_C9 = pd.read_csv('KeyWords_New/user_to_user_time_series_C5_C6_C9.csv')

# %%
len(user_to_user_time_series_C0_C1_C2)+len(user_to_user_time_series_C3_C4)+len(user_to_user_time_series_C5_C6_C9)
# Out:
# 390562

# %%
print(len(user_to_user_time_series_C0_C1_C2))
print(len(user_to_user_time_series_C3_C4))
print(len(user_to_user_time_series_C5_C6_C9))
# Out:
# 152069
# 115095
# 123398

# %%
user_to_user_time_series = user_to_user_time_series_C0_C1_C2.append([user_to_user_time_series_C3_C4, 
                                                                     user_to_user_time_series_C5_C6_C9], 
                                                                    ignore_index=True)
user_to_user_time_series.drop_duplicates(inplace=True)
user_to_user_time_series
# Out:
#                    dst              src  messages_sent  messages_received  \
# 0           a7madness1       a7madness1              1                  1
# 1             jrbrodin     aasianbokep2              0                  1
# 2       mauri_0fficial              aew              0                  1
# 3         declanjoyce9  aimingtoplease1              0                  2
# 4         akiramakkuro     akiramakkuro              1                  1
# ...                ...              ...            ...                ...
# 390557  nintendofrance   nintendofrance              1                  1
# 390558       kthtaexzx        kthtaexzx              1                  1
# 390559          15socl           15socl              1                  1
# 390560    joao__parker     joao__parker              1                  1
# 390561  julienrieutort   julienrieutort              1                  1
#
#         messages_total  contribution_index          start_time_  \
# ...

# %%
user_to_user_time_series.to_csv('KeyWords_New/user_to_user_time_series_All.csv')
