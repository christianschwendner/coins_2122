# %%
import pandas as pd
from functools import reduce
import math
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as md

# %%
# import of adj_mat
# import of nodes_cluster
# import of news_data
# import of crypto_data

# %% [markdown]
# # Import section

# %% [markdown]
# ## adj_mat

# %%
adj_mat = pd.read_csv('../Griffin_data/Adjacency_Matrix_Output_Currency.csv', index_col='Unnamed: 0') #, index_col='Unnamed: 0'

# %%
adj_mat
# Out:
#               date              src                  dst cluster_src  \
# 0       2021-10-24         tbwhale_         greatbuy2012          C7
# 1       2021-10-24         leerzeit        terry_twatter          C7
# 2       2021-10-24         leerzeit          neptune_xrp          C7
# 3       2021-10-24  twitsforbrains1              ivo_psd          C7
# 4       2021-10-24      garygensler             moonboyp          C7
# ...            ...              ...                  ...         ...
# 271687  2021-12-26     sol_kusanagi         dan_lisf1227          C5
# 271688  2021-12-26        dmsbigwin      dogevillage_bsc          C7
# 271689  2021-12-26        sol_lanas  [twitter_query=sol]          C7
# 271690  2021-12-26    bella2021hell  [twitter_query=sol]          C7
# 271691  2021-12-26  officialnovixel             coinkit_          C7
#
#         mes_sent  mes_received  mes_total  contr_index  sentiment_avg  \
# 0              1             0          1          1.0       0.275957
# 1              0             1          1         -1.0            NaN
# 2              0             1          1         -1.0            NaN
# 3              1             0          1          1.0       0.672842
# 4              0             1          1         -1.0            NaN
# ...          ...           ...        ...          ...            ...
# 271687         1             0          1          1.0            NaN
# 271688         1             0          1          1.0       0.526479
# 271689         1             1          2          0.0       0.149759
# 271690         1             1          2          0.0       0.049112
# 271691         2             0          2          1.0       0.929720
#
#         emoti_avg  compl_avg  neighbours cluster_dst  cluster_equal  \
# 0        0.157666   6.002466           2          C7           True
# 1             NaN        NaN         183          C7           True
# 2             NaN        NaN         183          C7           True
# 3        0.289887   6.478566           3          C7           True
# 4             NaN        NaN          28          C7           True
# ...           ...        ...         ...         ...            ...
# 271687        NaN        NaN           6          C5           True
# 271688   0.239496   6.140440           2          C7           True
# 271689   0.206458   8.186328           2          C7           True
# 271690   0.227122   6.826575           3          C7           True
# 271691   0.333058   5.977229         104          C7           True
#
#         neighbours_!cluster  neighbours_cluster twitter_query
# 0                         0                   2          ETH2
# 1                        10                 173          ETH2
# 2                        10                 173          ETH2
# 3                         0                   3          ETH2
# 4                         1                  27          ETH2
# ...                     ...                 ...           ...
# 271687                    0                   6           SOL
# 271688                    0                   2          DOGE
# 271689                    0                   2           SOL
# 271690                    1                   2           SOL
# 271691                    6                  98          SHIB
#
# [271692 rows x 17 columns]

# %%
adj_mat = adj_mat[['src', 'dst', 'date', 'cluster_src', 'neighbours', 'neighbours_cluster', 
                   'neighbours_!cluster', 'cluster_dst', 'twitter_query']]

# %%
adj_mat
# Out:
#                     src                  dst        date cluster_src  \
# 0              tbwhale_         greatbuy2012  2021-10-24          C7
# 1              leerzeit        terry_twatter  2021-10-24          C7
# 2              leerzeit          neptune_xrp  2021-10-24          C7
# 3       twitsforbrains1              ivo_psd  2021-10-24          C7
# 4           garygensler             moonboyp  2021-10-24          C7
# ...                 ...                  ...         ...         ...
# 271687     sol_kusanagi         dan_lisf1227  2021-12-26          C5
# 271688        dmsbigwin      dogevillage_bsc  2021-12-26          C7
# 271689        sol_lanas  [twitter_query=sol]  2021-12-26          C7
# 271690    bella2021hell  [twitter_query=sol]  2021-12-26          C7
# 271691  officialnovixel             coinkit_  2021-12-26          C7
#
#         neighbours  neighbours_cluster  neighbours_!cluster cluster_dst  \
# 0                2                   2                    0          C7
# 1              183                 173                   10          C7
# 2              183                 173                   10          C7
# 3                3                   3                    0          C7
# 4               28                  27                    1          C7
# ...            ...                 ...                  ...         ...
# 271687           6                   6                    0          C5
# 271688           2                   2                    0          C7
# 271689           2                   2                    0          C7
# 271690           3                   2                    1          C7
# 271691         104                  98                    6          C7
#
#        twitter_query
# 0               ETH2
# 1               ETH2
# 2               ETH2
# 3               ETH2
# 4               ETH2
# ...              ...
# 271687           SOL
# 271688          DOGE
# 271689           SOL
# 271690           SOL
# 271691          SHIB
#
# [271692 rows x 9 columns]

# %%
adj_mat_ETH2 = adj_mat.loc[adj_mat['twitter_query'] == 'ETH2']
adj_mat_SHIB = adj_mat.loc[adj_mat['twitter_query'] == 'SHIB']
adj_mat_SOL = adj_mat.loc[adj_mat['twitter_query'] == 'SOL']
adj_mat_ETH = adj_mat.loc[adj_mat['twitter_query'] == 'ETH']
adj_mat_LINK = adj_mat.loc[adj_mat['twitter_query'] == 'LINK']
adj_mat_BTC = adj_mat.loc[adj_mat['twitter_query'] == 'BTC']
adj_mat_DOGE = adj_mat.loc[adj_mat['twitter_query'] == 'DOGE']

# %%
adj_mat_SHIB
# Out:
#                     src              dst        date cluster_src  neighbours  \
# 9           bezoscrypto   ahmetcanakcan1  2021-10-24          C7          37
# 29        nook_ethereum       goxgoxgox2  2021-10-24          C6          12
# 41       ahmetcanakcan1      bezoscrypto  2021-10-24          C7           2
# 76             sftd_art         shibaxx1  2021-10-24          C0           2
# 77             sftd_art         shibaxx1  2021-10-24          C0           2
# ...                 ...              ...         ...         ...         ...
# 271646        kebunemas  doctorcreations  2021-12-26          C7           8
# 271647        kebunemas        anndylian  2021-12-26          C7           8
# 271650   dmingosshelper       queene_oce  2021-12-26          C5           1
# 271662        dmsbigwin     altgemhunter  2021-12-26          C7           2
# 271691  officialnovixel         coinkit_  2021-12-26          C7         104
#
#         neighbours_cluster  neighbours_!cluster cluster_dst twitter_query
# 9                       35                    2          C7          SHIB
# 29                      10                    2          C6          SHIB
# 41                       2                    0          C7          SHIB
# 76                       1                    1          C0          SHIB
# 77                       1                    1          C0          SHIB
# ...                    ...                  ...         ...           ...
# 271646                   8                    0          C7          SHIB
# 271647                   8                    0          C7          SHIB
# 271650                   1                    0          C5          SHIB
# 271662                   2                    0          C7          SHIB
# 271691                  98                    6          C7          SHIB
#
# [51775 rows x 9 columns]

# %% [markdown]
# ## nodes_cluster

# %% [markdown]
# ## news_data

# %% [markdown]
# ## crypto_data

# %%
df_ta_BTC = pd.read_csv('ta_df/df_ta_BTC.csv')
df_ta_SHIB = pd.read_csv('ta_df/df_ta_SHIB.csv')
df_ta_SOL = pd.read_csv('ta_df/df_ta_SOL.csv')
df_ta_ETH = pd.read_csv('ta_df/df_ta_ETH.csv')
df_ta_LINK = pd.read_csv('ta_df/df_ta_LINK.csv')
df_ta_DOGE = pd.read_csv('ta_df/df_ta_DOGE.csv')
df_ta_SHIB = pd.read_csv('ta_df/df_ta_SHIB.csv')

# %% [markdown]
# # Merging section (probably needed)

# %% [markdown]
# # Model definition (probably needed)

# %% [markdown]
# ## max. cluster strength

# %%
# cluster strength

#matrix input: src, dst, cluster_dst

## input:
### date
### cluster annotation per node, per day
## throughput1:
### number of neighbors inside cluster per node, per day
### number of total neighbors per node, per day (degree per node, per day)
## throughput2:
### (number of neighbors inside cluster per node, per day) / (degree per node, per day)
#### neighbours_cluster / neighbours
## output:
### lowest value of throughput2, per day

# %%
adj_mat['cluster_strength'] = adj_mat['neighbours_cluster'] / adj_mat['neighbours']
# Out:
# C:\Users\jgier\AppData\Local\Temp/ipykernel_14168/3199614937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adj_mat['cluster_strength'] = adj_mat['neighbours_cluster'] / adj_mat['neighbours']

# %%
adj_mat['date'] = pd.to_datetime(adj_mat['date'])
# Out:
# C:\Users\jgier\AppData\Local\Temp/ipykernel_14168/3939645140.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adj_mat['date'] = pd.to_datetime(adj_mat['date'])

# %%
adj_mat
# Out:
#                     src                  dst       date cluster_src  \
# 0              tbwhale_         greatbuy2012 2021-10-24          C7
# 1              leerzeit        terry_twatter 2021-10-24          C7
# 2              leerzeit          neptune_xrp 2021-10-24          C7
# 3       twitsforbrains1              ivo_psd 2021-10-24          C7
# 4           garygensler             moonboyp 2021-10-24          C7
# ...                 ...                  ...        ...         ...
# 215631     sol_kusanagi         dan_lisf1227 2021-12-26          C5
# 215632        dmsbigwin      dogevillage_bsc 2021-12-26          C7
# 215633        sol_lanas  [twitter_query=sol] 2021-12-26          C7
# 215634    bella2021hell  [twitter_query=sol] 2021-12-26          C7
# 215635  officialnovixel             coinkit_ 2021-12-26          C7
#
#         neighbours  neighbours_cluster  neighbours_!cluster cluster_dst  \
# 0                2                   2                    0          C7
# 1              183                 173                   10          C7
# 2              183                 173                   10          C7
# 3                3                   3                    0          C7
# 4               28                  27                    1          C7
# ...            ...                 ...                  ...         ...
# 215631           6                   6                    0          C5
# 215632           2                   2                    0          C7
# 215633           2                   2                    0          C7
# 215634           3                   2                    1          C7
# 215635         104                  98                    6          C7
#
#         cluster_strength
# 0               1.000000
# 1               0.945355
# 2               0.945355
# 3               1.000000
# 4               0.964286
# ...                  ...
# 215631          1.000000
# 215632          1.000000
# 215633          1.000000
# 215634          0.666667
# 215635          0.942308
#
# [215636 rows x 9 columns]

# %%
adj_mat[['cluster_strength']].hist('cluster_strength')
# Out:
# array([[<AxesSubplot:title={'center':'cluster_strength'}>]], dtype=object)

# %%
#adj_mat.groupby('cluster_src').min()

adj_mat_grouped = adj_mat.groupby([pd.Grouper(key='date', freq='D'),'cluster_src']).min()

# %%
adj_mat_grouped.sort_values('date').head(20)
# Out:
#                                         src                  dst  neighbours  \
# date       cluster_src
# 2021-10-24 C0                      sftd_art             sftd_art           2
#            C2                  ahmetbakrta6         ahmetbakrta6           1
#            C3                    gutterkhan           gutterkhan           1
#            C6                      atmpools             atmpools           1
#            C7                    10cryptoes           10cryptoes           1
# 2021-10-25 C2               1cyr7qajgctp8zg      1cyr7qajgctp8zg           1
#            C6                 bout_my_green        bout_my_green           1
#            C7                         1pyth                1pyth           1
# 2021-10-26 C8                      oxsocsci             oxsocsci           1
#            C7           [twitter_query=sol]  [twitter_query=sol]           1
#            C2                 _sleepybrowns        _sleepybrowns           1
#            C0                   boss__token          boss__token           2
#            C6                     cscpurnea            cscpurnea           1
# 2021-10-27 C2                  adamscochran         adamscochran           1
#            C4                     imbrue001            imbrue001           1
#            C6                         0xvvp                0xvvp           1
#            C7               2ucnewjdki9lcwm      2ucnewjdki9lcwm           1
# 2021-10-28 C7                       0x_kobe              0x_kobe           1
#            C6                    alexverdea           alexverdea           1
#            C0                chrisuniverseb       chrisuniverseb           2
#
#                         neighbours_cluster  neighbours_!cluster cluster_dst  \
# date       cluster_src
# 2021-10-24 C0                            1                    0          C0
#            C2                            1                    0          C2
#            C3                            1                    0          C3
#            C6                            1                    0          C2
#            C7                            1                    0          C2
# 2021-10-25 C2                            1                    0          C2
#            C6                            1                    0          C2
#            C7                            1                    0          C2
# 2021-10-26 C8                            1                    0          C8
#            C7                            1                    0          C7
#            C2                            1                    0          C2
#            C0                            1                    1          C0
#            C6                            1                    0          C6
# 2021-10-27 C2                            1                    0          C2
#            C4                            1                    0          C4
#            C6                            1                    0          C6
#            C7                            1                    0          C2
# 2021-10-28 C7                            1                    0          C0
#            C6                            1                    0          C2
#            C0                            2                    0          C0
#
#                         cluster_strength
# date       cluster_src
# 2021-10-24 C0                   0.500000
#            C2                   1.000000
#            C3                   1.000000
#            C6                   0.692308
#            C7                   0.500000
# 2021-10-25 C2                   0.500000
#            C6                   0.500000
#            C7                   0.600000
# 2021-10-26 C8                   1.000000
#            C7                   0.872727
#            C2                   0.640000
#            C0                   0.500000
#            C6                   1.000000
# 2021-10-27 C2                   0.500000
#            C4                   1.000000
#            C6                   1.000000
#            C7                   0.500000
# 2021-10-28 C7                   0.500000
#            C6                   0.600000
#            C0                   1.000000

# %%
#date, lowest cluster strength

cs_day = adj_mat.groupby(['date'])['cluster_strength'].min()
cs_day = cs_day.to_frame()
cs_day
# Out:
#             cluster_strength
# date
# 2021-10-24               0.5
# 2021-10-25               0.5
# 2021-10-26               0.5
# 2021-10-27               0.5
# 2021-10-28               0.5
# ...                      ...
# 2021-12-22               0.5
# 2021-12-23               0.5
# 2021-12-24               0.5
# 2021-12-25               0.5
# 2021-12-26               0.5
#
# [62 rows x 1 columns]

# %%
cs_day['cluster_strength'].unique()
cs_day.hist('cluster_strength')
# Out:
# array([[<AxesSubplot:title={'center':'cluster_strength'}>]], dtype=object)

# %%
adj_mat['cluster_strength'].min()
# Out:
# 0.5

# %% [markdown]
# For the scores it is important to note that the lowest value indicates that there is no stimulation for a shock reaction.
# In the model n = -1 means that there is the lowest possible amount of stimulation from the daily news sentiment whereas n = 1 means that there is the highest possible amount.

# %%
# cluster strength all in once

def cluster_strength(adj_mat):
    adj_mat['cluster_strength'] = adj_mat['neighbours_cluster'] / adj_mat['neighbours']
    
    adj_mat['date'] = pd.to_datetime(adj_mat['date'])
    adj_mat_grouped = adj_mat.groupby([pd.Grouper(key='date', freq='D'),'cluster_src']).min()
    
    # cluster strength
    cs_day = adj_mat.groupby(['date'])['cluster_strength'].min()
    cs_day = cs_day.to_frame()

    return cs_day

# %%
cs_day_BTC = cluster_strength(adj_mat_BTC)
# Out:
# C:\Users\Christian\AppData\Local\Temp\ipykernel_19596\728532119.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adj_mat['cluster_strength'] = adj_mat['neighbours_cluster'] / adj_mat['neighbours']
# C:\Users\Christian\AppData\Local\Temp\ipykernel_19596\728532119.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adj_mat['date'] = pd.to_datetime(adj_mat['date'])

# %%
# merge all

def merge_dataframe(df_ta, news_df, cs_day):
    df_ta = df_ta.rename(columns={'Date':'date'})


    df_ta['date'] = pd.to_datetime(df_ta['date'])
    news_df['date'] = pd.to_datetime(news_df['date'])
    cs_day = cs_day.reset_index()
    cs_day['date'] = pd.to_datetime(cs_day['date'])
    
    merge_1 = df_ta.merge(cs_day, on='date')
    merge_2 = merge_1.merge(news_df, on='date')
    merge_2
    
    merge_2.set_index('date', inplace=True)
    merge_2 = merge_2['2021-11-05':'2021-12-26']

    merged_cols = ['calculated_average', 'sentiment_bin', 'cluster_strength']
    df_final = merge_2[merged_cols]

    return df_final

# %%
df_final_BTC = merge_dataframe(df_ta_BTC, news_df_BTC, cs_day_BTC)
# Out:
# C:\Users\Christian\AppData\Local\Temp\ipykernel_19596\1210919689.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_df['date'] = pd.to_datetime(news_df['date'])

# %%
df_final_BTC
# Out:
#             calculated_average  sentiment_bin  cluster_strength
# date
# 2021-11-05                 0.2            0.0          0.500000
# 2021-11-05                 0.2            0.0          0.500000
# 2021-11-05                 0.2            0.0          0.500000
# 2021-11-05                 0.2           -1.0          0.500000
# 2021-11-06                 1.0           -1.0          1.000000
# ...                        ...            ...               ...
# 2021-12-22                -1.0            0.0          0.933333
# 2021-12-22                -1.0            0.0          0.933333
# 2021-12-22                -1.0            0.0          0.933333
# 2021-12-26                -0.2            0.0          0.500000
# 2021-12-26                -0.2            0.0          0.500000
#
# [78 rows x 3 columns]

# %%
def calculate_model(df_final):
    df = df_final.reset_index().copy()

    df = df[df.sentiment_bin != 'void']
    df = df[df.cluster_strength != 'void']

    df['calculated_average'] = pd.to_numeric(df['calculated_average'])
    df['sentiment_bin'] = pd.to_numeric(df['sentiment_bin'])
    df['cluster_strength'] = pd.to_numeric(df['cluster_strength'])

    # sum of scores
    df['x'] = df['sentiment_bin'] + df['calculated_average']

    # payoffs
    df['a'] = 0

    for index, row in df.iterrows():
        df.loc[index, 'a'] = 1 / (1 + math.exp( -(df.loc[index, 'x'])))

    df['b'] = 1 - df['a']

    # threshold
    df['q'] = df['b'] / (df['a'] + df['b'])

    df['1-q'] = 1 - df['q']

    df_result = df[['date', 'a', 'cluster_strength']].set_index('date')
    
    return df_result

# %%
df_result_BTC = calculate_model(df_final_BTC)

# %%
def plot_figure(df_result):
    plt.figure(figsize = (15,8))

    #ax = sns.lineplot(data=df, x='date', y="1-q")
    #ax = sns.lineplot(data=df, x='date', y="q")
    ax = sns.lineplot(data=df_result)

    # specify the position of the major ticks at the beginning of the week
    ax.xaxis.set_major_locator(md.WeekdayLocator(byweekday = 2))

    # specify the format of the labels as 'year-month-day'
    ax.xaxis.set_major_formatter(md.DateFormatter('%Y-%m-%d'))

    # (optional) rotate by 90° the labels in order to improve their spacing
    plt.setp(ax.xaxis.get_majorticklabels(), rotation = 90)

    # specify the position of the minor ticks at each day
    ax.xaxis.set_minor_locator(md.DayLocator(interval = 1))

    ax.tick_params(axis = 'x', which = 'major', length = 10)
    ax.tick_params(axis = 'x', which = 'minor', length = 5)

    #ax.set_title('1-q / Treshold')

    plt.show()

# %%
plot_figure(df_result_BTC)

# %% [markdown]
# ## sentiment score

# %%
news_df = pd.read_excel('../GPT-3_Approach/output_data_sentiment.xlsx', index_col='Unnamed: 0').drop(columns=['Unnamed: 0.1','Unnamed: 0.1.1'])

# %%
news_df['Query'] = news_df['Query'].str.replace('bitcoin', 'BTC')
news_df['Query'] = news_df['Query'].str.replace('ethereum2', 'ETH2')
news_df['Query'] = news_df['Query'].str.replace('shibainucoin', 'SHIB')
news_df['Query'] = news_df['Query'].str.replace('solana', 'SOL')
news_df['Query'] = news_df['Query'].str.replace('ethereum', 'ETH')
news_df['Query'] = news_df['Query'].str.replace('Chainlink', 'LINK')
news_df['Query'] = news_df['Query'].str.replace('dogecoin', 'DOGE')

# %%
news_df_BTC = news_df.loc[news_df['Query'] == 'BTC']
news_df_ETH2 = news_df.loc[news_df['Query'] == 'ETH2']
news_df_SHIB = news_df.loc[news_df['Query'] == 'SHIB']
news_df_SOL = news_df.loc[news_df['Query'] == 'SOL']
news_df_ETH = news_df.loc[news_df['Query'] == 'ETH']
news_df_LINK = news_df.loc[news_df['Query'] == 'LINK']
news_df_DOGE = news_df.loc[news_df['Query'] == 'DOGE']

# %% [markdown]
# ## indicator score

# %%
df_ta
# Out:
#                  Date         Close       Volume  signal_rsi  signal_bb  \
# Date
# 2017-02-13 2017-02-13    990.642029    100607000           0          0
# 2017-02-14 2017-02-14   1004.549988    137946000           0          0
# 2017-02-15 2017-02-15   1007.479980     89759400           0          0
# 2017-02-16 2017-02-16   1027.439941    122277000           0          0
# 2017-02-17 2017-02-17   1046.209961    136474000           0          0
# ...               ...           ...          ...         ...        ...
# 2022-01-20 2022-01-20  40680.417969  20382033940           0          0
# 2022-01-21 2022-01-21  36457.316406  43011992031           0          2
# 2022-01-22 2022-01-22  35030.250000  39714385405           0          2
# 2022-01-23 2022-01-23  36276.804688  26017975951           0          0
# 2022-01-24 2022-01-24  34033.199219  34261772288           0          2
#
#             signal_obv  signal_mva  calculated_average
# Date
# 2017-02-13          -2          -2                -1.0
# 2017-02-14           2          -2                -0.2
# 2017-02-15           2          -2                -0.2
# 2017-02-16           2          -2                -0.2
# 2017-02-17           2          -2                -0.2
# ...                ...         ...                 ...
# 2022-01-20          -2          -2                -1.0
# 2022-01-21          -2          -2                -0.4
# 2022-01-22          -2          -2                -0.4
# 2022-01-23           2          -2                -0.2
# 2022-01-24          -2          -2                -0.4
#
# [1807 rows x 8 columns]

# %%
df_ta = df_ta.loc['2021-10-21':'2021-12-31']
df_ta
# Out:
#                  Date         Close       Volume  signal_rsi  signal_bb  \
# Date
# 2021-10-21 2021-10-21  62210.171875  45908121370           0          0
# 2021-10-22 2021-10-22  60692.265625  38434082775           0          0
# 2021-10-23 2021-10-23  61393.617188  26882546034           0          0
# 2021-10-24 2021-10-24  60930.835938  27316183882           0          0
# 2021-10-25 2021-10-25  63039.824219  31064911614           0          0
# ...               ...           ...          ...         ...        ...
# 2021-12-27 2021-12-27  50640.417969  24324345758           0          0
# 2021-12-28 2021-12-28  47588.855469  33430376883           0          0
# 2021-12-29 2021-12-29  46444.710938  30049226299           0          0
# 2021-12-30 2021-12-30  47178.125000  26686491018           0          0
# 2021-12-31 2021-12-31  46306.445312  36974172400           0          0
#
#             signal_obv  signal_mva  calculated_average
# Date
# 2021-10-21          -2           2                 0.2
# 2021-10-22          -2           2                 0.2
# 2021-10-23           2           2                 1.0
# 2021-10-24          -2           2                 0.2
# 2021-10-25           2           2                 1.0
# ...                ...         ...                 ...
# 2021-12-27          -2          -2                -1.0
# 2021-12-28          -2          -2                -1.0
# 2021-12-29          -2          -2                -1.0
# 2021-12-30           2          -2                -0.2
# 2021-12-31          -2          -2                -1.0
#
# [72 rows x 8 columns]

# %%
df_ta.describe()
# Out:
#               Close        Volume  signal_rsi  signal_bb  signal_obv  \
# count     72.000000  7.200000e+01        72.0  72.000000   72.000000
# mean   55819.096300  3.340240e+10         0.0   0.027778   -0.222222
# std     6487.504301  7.198025e+09         0.0   0.530007    2.001564
# min    46202.144531  1.903065e+10         0.0  -2.000000   -2.000000
# 25%    49367.262695  2.819713e+10         0.0   0.000000   -2.000000
# 50%    57117.626953  3.249791e+10         0.0   0.000000   -2.000000
# 75%    61337.622070  3.703018e+10         0.0   0.000000    2.000000
# max    67566.828125  6.138568e+10         0.0   2.000000    2.000000
#
#        signal_mva  calculated_average
# count   72.000000           72.000000
# mean     0.055556           -0.019444
# std      2.013258            0.688873
# min     -2.000000           -1.000000
# 25%     -2.000000           -0.400000
# 50%      2.000000            0.200000
# 75%      2.000000            0.200000
# max      2.000000            1.000000

# %%
df_ta.hist('calculated_average')
# Out:
# array([[<AxesSubplot:title={'center':'calculated_average'}>]],
#       dtype=object)

# %% [markdown]
# ## Processing of dataframe

# %%
df_ta.rename(columns={'Date':'date'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [58], in <module>
# ----> 1 df_ta.rename(columns={'Date':'date'}, inplace=True)
#
# NameError: name 'df_ta' is not defined

# %%
news_df
# Out:
#                                                  author  \
# 0                                        Richard Lawler
# 1                mfox@businessinsider.com (Matthew Fox)
# 2                                    Entrepreneur Staff
# 3                                                   NaN
# 4                                         Reuters Staff
# ...                                                 ...
# 1884               newsfeedback@fool.com (Adria Cimino)
# 1885                                         Paul Vigna
# 1886  Kenneth Rapoza, Senior Contributor, \n Kenneth...
# 1888                                      Shaurya Malwa
# 1889  Clem Chambers, Senior Contributor, \n Clem Cha...
#
#                                                   title  \
# 0     A fake press release claiming Kroger accepts c...
# 1     An ethereum futures ETF will be available befo...
# 2                              Bitcoin Trades 7% Higher
# 3     Bitcoin hits new record as crypto market cap e...
# 4     Bitcoin hits new record as crypto market cap e...
# ...                                                 ...
# 1884                           3 Reasons to Buy Cardano
# 1885  NFTs and SNL: Crypto Keeps Burrowing Into Main...
# 1886  Where To Put $1,000 In Your Cryptocurrency Por...
# 1888  Fantom Surges as Investors Seach for Next Laye...
# 1889    3 Cryptos For 2022: Bitcoin, Matic And Compound
#
#                                             description  \
# 0     A crypto hoax claimed Kroger is accepting Bitc...
# 1     "Though a spot Bitcoin ETF is possible in 2022...
# 2     Bitcoin was trading over 7% higher on Monday m...
# 3     Bitcoin and ether made record peaks in the Asi...
# 4     Bitcoin and ether made record peaks in the Asi...
# ...                                                 ...
# 1884                 Many catalysts are on the horizon.
# 1885  It was another crazy year in the crypto world,...
# 1886  What will the hot sectors in cryptocurrency in...
# 1888  FTM tokens are rallying even as the broader ma...
# 1889  In crypto the general laws of investing apply....
#
#                                                     url  \
# 0     https://www.theverge.com/2021/11/5/22765098/kr...
# 1     https://markets.businessinsider.com/news/curre...
# 2           https://www.entrepreneur.com/article/395938
# 3     https://www.reuters.com/technology/bitcoin-hit...
# 4     https://www.reuters.com/article/fintech-crypto...
# ...                                                 ...
# 1884  https://www.fool.com/investing/2021/12/28/3-re...
# 1885  https://www.wsj.com/articles/nfts-and-snl-cryp...
# 1886  https://www.forbes.com/sites/kenrapoza/2021/12...
# 1888  https://finance.yahoo.com/news/fantom-surges-i...
# 1889  https://www.forbes.com/sites/investor/2021/12/...
#
#                                              urlToImage         publishedAt  \
# 0     https://cdn.vox-cdn.com/thumbor/CKp0YjnwF88--m... 2021-11-05 13:32:14
# 1     https://images2.markets.businessinsider.com/61... 2021-11-06 12:15:00
# 2     https://assets.entrepreneur.com/content/3x2/20... 2021-11-08 16:07:45
# 3     https://www.reuters.com/resizer/InHvCiSZm4U-VU... 2021-11-08 23:38:00
# 4     https://static.reuters.com/resources/r/?m=02&d... 2021-11-08 23:37:00
# ...                                                 ...                 ...
# 1884  https://g.foolcdn.com/editorial/images/658831/... 2021-12-28 11:00:00
# 1885            https://images.wsj.net/im-456771/social 2021-12-27 11:52:41
# 1886  https://thumbor.forbes.com/thumbor/fit-in/1200... 2021-12-29 13:30:00
# 1888  https://s.yimg.com/uu/api/res/1.2/hXU_4XMXUJ76... 2021-12-29 09:23:05
# 1889  https://thumbor.forbes.com/thumbor/fit-in/1200... 2021-12-28 12:39:01
#
#                                                 content  \
# 0     A similar hoax earlier this year tied Walmart ...
# 1     Ether.\nNurPhoto\n<ul><li>The approval of a bi...
# 2     Bitcoin was trading over 7% higher on Monday m...
# 3     A representation of the virtual cryptocurrency...
# 4     By Reuters Staff\nFILE PHOTO: A representation...
# ...                                                 ...
# 1884  There are thousands of cryptocurrencies out th...
# 1885  Crypto has been many things in its short histo...
# 1886  What sectors of the crypto market should you c...
# 1888  Tokens of layer 1 blockchain Fantom (FTM) were...
# 1889  getty\ngetty\nA lot of people have made a lot ...
#
#                     source.id              source.name      Query  \
# 0                   the-verge                The Verge    bitcoin
# 1            business-insider         Business Insider    bitcoin
# 2                         NaN             Entrepreneur    bitcoin
# 3                     reuters                  Reuters    bitcoin
# 4                     reuters                  Reuters    bitcoin
# ...                       ...                      ...        ...
# 1884                      NaN              Motley Fool  ethereum2
# 1885  the-wall-street-journal  The Wall Street Journal  ethereum2
# 1886                      NaN                   Forbes  ethereum2
# 1888                      NaN      Yahoo Entertainment  ethereum2
# 1889                      NaN                   Forbes  ethereum2
#
#                                                   merge sentiment  topic  \
# 0     A fake press release claiming Kroger accepts c...  Negative    NaN
# 1     An ethereum futures ETF will be available befo...   Neutral    NaN
# 2     Bitcoin Trades 7% Higher; Bitcoin was trading ...  Positive    NaN
# 3     Bitcoin hits new record as crypto market cap e...  Positive    NaN
# 4     Bitcoin hits new record as crypto market cap e...  Positive    NaN
# ...                                                 ...       ...    ...
# 1884  3 Reasons to Buy Cardano; Many catalysts are o...  Positive    NaN
# 1885  NFTs and SNL: Crypto Keeps Burrowing Into Main...  Positive    NaN
# 1886  Where To Put $1,000 In Your Cryptocurrency Por...   Neutral    NaN
# 1888  Fantom Surges as Investors Seach for Next Laye...  Positive    NaN
# 1889  3 Cryptos For 2022: Bitcoin, Matic And Compoun...  Positive    NaN
#
#       sentiment_bin       date
# 0               0.0 2021-11-05
# 1              -1.0 2021-11-06
# 2               0.0 2021-11-08
# 3               0.0 2021-11-08
# 4               0.0 2021-11-08
# ...             ...        ...
# 1884            0.0 2021-12-28
# 1885            0.0 2021-12-27
# 1886           -1.0 2021-12-29
# 1888            0.0 2021-12-29
# 1889            0.0 2021-12-28
#
# [1864 rows x 15 columns]

# %%
cs_day
# Out:
#             cluster_strength
# date
# 2021-10-24               0.5
# 2021-10-25               0.5
# 2021-10-26               0.5
# 2021-10-27               0.5
# 2021-10-28               0.5
# ...                      ...
# 2021-12-22               0.5
# 2021-12-23               0.5
# 2021-12-24               0.5
# 2021-12-25               0.5
# 2021-12-26               0.5
#
# [62 rows x 1 columns]

# %%
news_df.merge
# Out:
# <bound method DataFrame.merge of                                                  author  \
# 0                                        Richard Lawler
# 1                mfox@businessinsider.com (Matthew Fox)
# 2                                    Entrepreneur Staff
# 3                                                   NaN
# 4                                         Reuters Staff
# ...                                                 ...
# 1884               newsfeedback@fool.com (Adria Cimino)
# 1885                                         Paul Vigna
# 1886  Kenneth Rapoza, Senior Contributor, \n Kenneth...
# 1888                                      Shaurya Malwa
# 1889  Clem Chambers, Senior Contributor, \n Clem Cha...
#
#                                                   title  \
# 0     A fake press release claiming Kroger accepts c...
# 1     An ethereum futures ETF will be available befo...
# 2                              Bitcoin Trades 7% Higher
# 3     Bitcoin hits new record as crypto market cap e...
# 4     Bitcoin hits new record as crypto market cap e...
# ...                                                 ...
# 1884                           3 Reasons to Buy Cardano
# 1885  NFTs and SNL: Crypto Keeps Burrowing Into Main...
# 1886  Where To Put $1,000 In Your Cryptocurrency Por...
# 1888  Fantom Surges as Investors Seach for Next Laye...
# 1889    3 Cryptos For 2022: Bitcoin, Matic And Compound
#
#                                             description  \
# 0     A crypto hoax claimed Kroger is accepting Bitc...
# 1     "Though a spot Bitcoin ETF is possible in 2022...
# 2     Bitcoin was trading over 7% higher on Monday m...
# 3     Bitcoin and ether made record peaks in the Asi...
# 4     Bitcoin and ether made record peaks in the Asi...
# ...                                                 ...
# 1884                 Many catalysts are on the horizon.
# 1885  It was another crazy year in the crypto world,...
# 1886  What will the hot sectors in cryptocurrency in...
# 1888  FTM tokens are rallying even as the broader ma...
# 1889  In crypto the general laws of investing apply....
#
#                                                     url  \
# 0     https://www.theverge.com/2021/11/5/22765098/kr...
# 1     https://markets.businessinsider.com/news/curre...
# 2           https://www.entrepreneur.com/article/395938
# 3     https://www.reuters.com/technology/bitcoin-hit...
# 4     https://www.reuters.com/article/fintech-crypto...
# ...                                                 ...
# 1884  https://www.fool.com/investing/2021/12/28/3-re...
# 1885  https://www.wsj.com/articles/nfts-and-snl-cryp...
# 1886  https://www.forbes.com/sites/kenrapoza/2021/12...
# 1888  https://finance.yahoo.com/news/fantom-surges-i...
# 1889  https://www.forbes.com/sites/investor/2021/12/...
#
#                                              urlToImage         publishedAt  \
# 0     https://cdn.vox-cdn.com/thumbor/CKp0YjnwF88--m... 2021-11-05 13:32:14
# 1     https://images2.markets.businessinsider.com/61... 2021-11-06 12:15:00
# 2     https://assets.entrepreneur.com/content/3x2/20... 2021-11-08 16:07:45
# 3     https://www.reuters.com/resizer/InHvCiSZm4U-VU... 2021-11-08 23:38:00
# 4     https://static.reuters.com/resources/r/?m=02&d... 2021-11-08 23:37:00
# ...                                                 ...                 ...
# 1884  https://g.foolcdn.com/editorial/images/658831/... 2021-12-28 11:00:00
# 1885            https://images.wsj.net/im-456771/social 2021-12-27 11:52:41
# 1886  https://thumbor.forbes.com/thumbor/fit-in/1200... 2021-12-29 13:30:00
# 1888  https://s.yimg.com/uu/api/res/1.2/hXU_4XMXUJ76... 2021-12-29 09:23:05
# 1889  https://thumbor.forbes.com/thumbor/fit-in/1200... 2021-12-28 12:39:01
#
#                                                 content  \
# 0     A similar hoax earlier this year tied Walmart ...
# 1     Ether.\nNurPhoto\n<ul><li>The approval of a bi...
# 2     Bitcoin was trading over 7% higher on Monday m...
# 3     A representation of the virtual cryptocurrency...
# 4     By Reuters Staff\nFILE PHOTO: A representation...
# ...                                                 ...
# 1884  There are thousands of cryptocurrencies out th...
# 1885  Crypto has been many things in its short histo...
# 1886  What sectors of the crypto market should you c...
# 1888  Tokens of layer 1 blockchain Fantom (FTM) were...
# 1889  getty\ngetty\nA lot of people have made a lot ...
#
#                     source.id              source.name      Query  \
# 0                   the-verge                The Verge    bitcoin
# 1            business-insider         Business Insider    bitcoin
# 2                         NaN             Entrepreneur    bitcoin
# 3                     reuters                  Reuters    bitcoin
# 4                     reuters                  Reuters    bitcoin
# ...                       ...                      ...        ...
# 1884                      NaN              Motley Fool  ethereum2
# 1885  the-wall-street-journal  The Wall Street Journal  ethereum2
# 1886                      NaN                   Forbes  ethereum2
# 1888                      NaN      Yahoo Entertainment  ethereum2
# 1889                      NaN                   Forbes  ethereum2
#
#                                                   merge sentiment  topic  \
# 0     A fake press release claiming Kroger accepts c...  Negative    NaN
# 1     An ethereum futures ETF will be available befo...   Neutral    NaN
# 2     Bitcoin Trades 7% Higher; Bitcoin was trading ...  Positive    NaN
# 3     Bitcoin hits new record as crypto market cap e...  Positive    NaN
# 4     Bitcoin hits new record as crypto market cap e...  Positive    NaN
# ...                                                 ...       ...    ...
# 1884  3 Reasons to Buy Cardano; Many catalysts are o...  Positive    NaN
# 1885  NFTs and SNL: Crypto Keeps Burrowing Into Main...  Positive    NaN
# 1886  Where To Put $1,000 In Your Cryptocurrency Por...   Neutral    NaN
# 1888  Fantom Surges as Investors Seach for Next Laye...  Positive    NaN
# 1889  3 Cryptos For 2022: Bitcoin, Matic And Compoun...  Positive    NaN
#
#       sentiment_bin       date
# 0               0.0 2021-11-05
# 1              -1.0 2021-11-06
# 2               0.0 2021-11-08
# 3               0.0 2021-11-08
# 4               0.0 2021-11-08
# ...             ...        ...
# 1884            0.0 2021-12-28
# 1885            0.0 2021-12-27
# 1886           -1.0 2021-12-29
# 1888            0.0 2021-12-29
# 1889            0.0 2021-12-28
#
# [1864 rows x 15 columns]>

# %%
news_df_BTC.head(2)
# Out:
#                                    author  \
# 0                          Richard Lawler
# 1  mfox@businessinsider.com (Matthew Fox)
#
#                                                title  \
# 0  A fake press release claiming Kroger accepts c...
# 1  An ethereum futures ETF will be available befo...
#
#                                          description  \
# 0  A crypto hoax claimed Kroger is accepting Bitc...
# 1  "Though a spot Bitcoin ETF is possible in 2022...
#
#                                                  url  \
# 0  https://www.theverge.com/2021/11/5/22765098/kr...
# 1  https://markets.businessinsider.com/news/curre...
#
#                                           urlToImage         publishedAt  \
# 0  https://cdn.vox-cdn.com/thumbor/CKp0YjnwF88--m... 2021-11-05 13:32:14
# 1  https://images2.markets.businessinsider.com/61... 2021-11-06 12:15:00
#
#                                              content         source.id  \
# 0  A similar hoax earlier this year tied Walmart ...         the-verge
# 1  Ether.\nNurPhoto\n<ul><li>The approval of a bi...  business-insider
#
#         source.name Query                                              merge  \
# 0         The Verge   BTC  A fake press release claiming Kroger accepts c...
# 1  Business Insider   BTC  An ethereum futures ETF will be available befo...
#
#   sentiment  topic  sentiment_bin       date
# 0  Negative    NaN            0.0 2021-11-05
# 1   Neutral    NaN           -1.0 2021-11-06

# %%
news_df_BTC
# Out:
#                                          author  \
# 0                                Richard Lawler
# 1        mfox@businessinsider.com (Matthew Fox)
# 2                            Entrepreneur Staff
# 3                                           NaN
# 4                                 Reuters Staff
# ...                                         ...
# 1767                 jma@insider.com (Jason Ma)
# 1768                               Joshua Sophy
# 1769  info@hypebeast.com (HYPEBEAST), HYPEBEAST
# 1770                                        NaN
# 1771                                        NaN
#
#                                                   title  \
# 0     A fake press release claiming Kroger accepts c...
# 1     An ethereum futures ETF will be available befo...
# 2                              Bitcoin Trades 7% Higher
# 3     Bitcoin hits new record as crypto market cap e...
# 4     Bitcoin hits new record as crypto market cap e...
# ...                                                 ...
# 1767  S&P 500 hits fresh record high as US stocks ex...
# 1768                    Who Accepts Bitcoin as Payment?
# 1769  New England Patriots Quarterback Mac Jones Gif...
# 1770  Overview of El Salvador's official yet controv...
# 1771  100s of El Salvadorans Report Bitcoins Disappe...
#
#                                             description  \
# 0     A crypto hoax claimed Kroger is accepting Bitc...
# 1     "Though a spot Bitcoin ETF is possible in 2022...
# 2     Bitcoin was trading over 7% higher on Monday m...
# 3     Bitcoin and ether made record peaks in the Asi...
# 4     Bitcoin and ether made record peaks in the Asi...
# ...                                                 ...
# 1767  After setting its 68th record close of 2021 on...
# 1768  As the top cryptocurrency, Bitcoin has seen ex...
# 1769  New England Patriots quarterback Michael McCor...
# 1770  Scott Chipolina / Decrypt:\nOverview of El Sal...
# 1771  Hundreds of El Salvador citizens inexplicably ...
#
#                                                     url  \
# 0     https://www.theverge.com/2021/11/5/22765098/kr...
# 1     https://markets.businessinsider.com/news/curre...
# 2           https://www.entrepreneur.com/article/395938
# 3     https://www.reuters.com/technology/bitcoin-hit...
# 4     https://www.reuters.com/article/fintech-crypto...
# ...                                                 ...
# 1767  https://markets.businessinsider.com/news/stock...
# 1768  https://smallbiztrends.com/2021/12/who-accepts...
# 1769  https://hypebeast.com/2021/12/new-england-patr...
# 1770                 https://www.techmeme.com/211228/p3
# 1771  https://thecryptobasic.com/2021/12/25/hundreds...
#
#                                              urlToImage         publishedAt  \
# 0     https://cdn.vox-cdn.com/thumbor/CKp0YjnwF88--m... 2021-11-05 13:32:14
# 1     https://images2.markets.businessinsider.com/61... 2021-11-06 12:15:00
# 2     https://assets.entrepreneur.com/content/3x2/20... 2021-11-08 16:07:45
# 3     https://www.reuters.com/resizer/InHvCiSZm4U-VU... 2021-11-08 23:38:00
# 4     https://static.reuters.com/resources/r/?m=02&d... 2021-11-08 23:37:00
# ...                                                 ...                 ...
# 1767  https://images2.markets.businessinsider.com/61... 2021-12-27 14:35:27
# 1768  https://media.smallbiztrends.com/2021/12/who-a... 2021-12-28 14:00:59
# 1769  https://image-cdn.hypb.st/https%3A%2F%2Fhypebe... 2021-12-28 01:37:58
# 1770  https://cdn.decrypt.co/resize/1024/height/512/... 2021-12-28 12:30:02
# 1771  https://thecryptobasic.com/wp-content/uploads/... 2021-12-26 14:08:04
#
#                                                 content         source.id  \
# 0     A similar hoax earlier this year tied Walmart ...         the-verge
# 1     Ether.\nNurPhoto\n<ul><li>The approval of a bi...  business-insider
# 2     Bitcoin was trading over 7% higher on Monday m...               NaN
# 3     A representation of the virtual cryptocurrency...           reuters
# 4     By Reuters Staff\nFILE PHOTO: A representation...           reuters
# ...                                                 ...               ...
# 1767  Trader Leon Montana works on the floor of the ...  business-insider
# 1768  Over the years, Bitcoin has significantly domi...               NaN
# 1769  New England Patriots quarterback Michael McCor...               NaN
# 1770  CB Insights Newsletter\n724,948 subscribers ge...               NaN
# 1771  Hundreds of El Salvador citizens inexplicably ...               NaN
#
#                 source.name Query  \
# 0                 The Verge   BTC
# 1          Business Insider   BTC
# 2              Entrepreneur   BTC
# 3                   Reuters   BTC
# 4                   Reuters   BTC
# ...                     ...   ...
# 1767       Business Insider   BTC
# 1768  Small Business Trends   BTC
# 1769              HYPEBEAST   BTC
# 1770           Techmeme.com   BTC
# 1771     Thecryptobasic.com   BTC
#
#                                                   merge sentiment  topic  \
# 0     A fake press release claiming Kroger accepts c...  Negative    NaN
# 1     An ethereum futures ETF will be available befo...   Neutral    NaN
# 2     Bitcoin Trades 7% Higher; Bitcoin was trading ...  Positive    NaN
# 3     Bitcoin hits new record as crypto market cap e...  Positive    NaN
# 4     Bitcoin hits new record as crypto market cap e...  Positive    NaN
# ...                                                 ...       ...    ...
# 1767  S&P 500 hits fresh record high as US stocks ex...  Positive    NaN
# 1768  Who Accepts Bitcoin as Payment?; As the top cr...  Positive    NaN
# 1769  New England Patriots Quarterback Mac Jones Gif...  Positive    NaN
# 1770  Overview of El Salvador's official yet controv...  Positive    NaN
# 1771  100s of El Salvadorans Report Bitcoins Disappe...  Negative    NaN
#
#       sentiment_bin       date
# 0               0.0 2021-11-05
# 1              -1.0 2021-11-06
# 2               0.0 2021-11-08
# 3               0.0 2021-11-08
# 4               0.0 2021-11-08
# ...             ...        ...
# 1767            0.0 2021-12-27
# 1768            0.0 2021-12-28
# 1769            0.0 2021-12-28
# 1770            0.0 2021-12-28
# 1771            0.0 2021-12-26
#
# [280 rows x 15 columns]

# %%
df_ta_BTC['date'] = pd.to_datetime(df_ta_BTC['date'])
news_df_BTC['date'] = pd.to_datetime(news_df_BTC['date'])
cs_day_BTC = cs_day_BTC.reset_index()
cs_day_BTC['date'] = pd.to_datetime(cs_day_BTC['date'])
# Out:
# C:\Users\Christian\AppData\Local\Temp\ipykernel_19596\740311922.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   news_df_BTC['date'] = pd.to_datetime(news_df_BTC['date'])

# %%
cs_day_BTC
# Out:
#     index       date  cluster_strength
# 0       0 2021-10-27          0.571429
# 1       1 2021-10-31          0.500000
# 2       2 2021-11-05          0.500000
# 3       3 2021-11-06          1.000000
# 4       4 2021-11-07          0.500000
# 5       5 2021-11-22          0.666667
# 6       6 2021-11-23          1.000000
# 7       7 2021-11-24          0.666667
# 8       8 2021-11-28          0.500000
# 9       9 2021-12-03          0.750000
# 10     10 2021-12-04          0.500000
# 11     11 2021-12-05          0.500000
# 12     12 2021-12-07          0.500000
# 13     13 2021-12-11          0.500000
# 14     14 2021-12-12          0.500000
# 15     15 2021-12-15          0.750000
# 16     16 2021-12-16          0.600000
# 17     17 2021-12-19          0.500000
# 18     18 2021-12-20          0.500000
# 19     19 2021-12-22          0.933333
# 20     20 2021-12-26          0.500000

# %%
merge_1 = df_ta_BTC.merge(cs_day_BTC, on='date')
merge_2 = merge_1.merge(news_df_BTC, on='date')
merge_2
# Out:
#          date      Date.1         Close       Volume  signal_rsi  signal_bb  \
# 0  2021-11-05  2021-11-05  61125.675781  30605102446           0          0
# 1  2021-11-05  2021-11-05  61125.675781  30605102446           0          0
# 2  2021-11-05  2021-11-05  61125.675781  30605102446           0          0
# 3  2021-11-05  2021-11-05  61125.675781  30605102446           0          0
# 4  2021-11-06  2021-11-06  61527.480469  29094934221           0          0
# ..        ...         ...           ...          ...         ...        ...
# 73 2021-12-22  2021-12-22  48628.511719  24447979559           0          0
# 74 2021-12-22  2021-12-22  48628.511719  24447979559           0          0
# 75 2021-12-22  2021-12-22  48628.511719  24447979559           0          0
# 76 2021-12-26  2021-12-26  50809.515625  20964372926           0          0
# 77 2021-12-26  2021-12-26  50809.515625  20964372926           0          0
#
#     signal_obv  signal_mva  calculated_average ta_query  ...  \
# 0           -2           2                 0.2      BTC  ...
# 1           -2           2                 0.2      BTC  ...
# 2           -2           2                 0.2      BTC  ...
# 3           -2           2                 0.2      BTC  ...
# 4            2           2                 1.0      BTC  ...
# ..         ...         ...                 ...      ...  ...
# 73          -2          -2                -1.0      BTC  ...
# 74          -2          -2                -1.0      BTC  ...
# 75          -2          -2                -1.0      BTC  ...
# 76           2          -2                -0.2      BTC  ...
# 77           2          -2                -0.2      BTC  ...
#
#                                            urlToImage         publishedAt  \
# 0   https://cdn.vox-cdn.com/thumbor/CKp0YjnwF88--m... 2021-11-05 13:32:14
# 1   https://images2.markets.businessinsider.com/61... 2021-11-05 12:06:22
# 2         https://a.fsdn.com/sd/topics/bitcoin_64.png 2021-11-05 00:50:00
# 3   https://www.reuters.com/resizer/9mqfV1phfYALJK... 2021-11-05 08:12:00
# 4   https://images2.markets.businessinsider.com/61... 2021-11-06 12:15:00
# ..                                                ...                 ...
# 73  https://www.reuters.com/pf/resources/images/re... 2021-12-22 04:35:00
# 74  https://www.reuters.com/resizer/h9AaU069mwRQvt... 2021-12-22 15:07:00
# 75  https://images2.markets.businessinsider.com/61... 2021-12-22 21:13:17
# 76  https://media.wired.com/photos/61bd32b4b540f6b... 2021-12-26 13:00:00
# 77  https://thecryptobasic.com/wp-content/uploads/... 2021-12-26 14:08:04
#
#                                               content         source.id  \
# 0   A similar hoax earlier this year tied Walmart ...         the-verge
# 1   Ethereum and bitcoin are the two biggest crypt...  business-insider
# 2   "NYC is going to be the center of the cryptocu...               NaN
# 3   Representations of the virtual currency Bitcoi...           reuters
# 4   Ether.\nNurPhoto\n<ul><li>The approval of a bi...  business-insider
# ..                                                ...               ...
# 73  HONG KONG, Dec 22 (Reuters) - The Aussie and K...           reuters
# 74  NEW YORK, Dec 22 (Reuters) - The euro, Austral...           reuters
# 75  Holiday decorations adorn the floor of the New...  business-insider
# 76  In the future, luxury brands may have storefro...             wired
# 77  Hundreds of El Salvador citizens inexplicably ...               NaN
#
#            source.name Query  \
# 0            The Verge   BTC
# 1     Business Insider   BTC
# 2         Slashdot.org   BTC
# 3              Reuters   BTC
# 4     Business Insider   BTC
# ..                 ...   ...
# 73             Reuters   BTC
# 74             Reuters   BTC
# 75    Business Insider   BTC
# 76               Wired   BTC
# 77  Thecryptobasic.com   BTC
#
#                                                 merge sentiment topic  \
# 0   A fake press release claiming Kroger accepts c...  Negative   NaN
# 1   JPMorgan says ethereum is a better bet than bi...  Positive   NaN
# 2   Incoming New York Mayor Eric Adams Vows To Tak...  Positive   NaN
# 3   Australia's banking regulator looks into CBA's...   Neutral   NaN
# 4   An ethereum futures ETF will be available befo...   Neutral   NaN
# ..                                                ...       ...   ...
# 73  Dollar regains ground as volatility starts to ...  Positive   NaN
# 74  Dollar slips while Aussie and Norwegian crown ...  Positive   NaN
# 75  US stocks surge in thin trading day ahead of h...  Positive   NaN
# 76  The Metaverse Land Rush Is an Illusion; The “r...  Negative   NaN
# 77  100s of El Salvadorans Report Bitcoins Disappe...  Negative   NaN
#
#    sentiment_bin
# 0            0.0
# 1            0.0
# 2            0.0
# 3           -1.0
# 4           -1.0
# ..           ...
# 73           0.0
# 74           0.0
# 75           0.0
# 76           0.0
# 77           0.0
#
# [78 rows x 26 columns]

# %%
merged.loc['2021-10-25':'2021-12-26']
# Out:
#                 Date.1         Close        Volume  signal_rsi  signal_bb  \
# date
# 2021-10-25  2021-10-25  63039.824219  3.106491e+10         0.0        0.0
# 2021-10-26  2021-10-26  60363.792969  3.487897e+10         0.0        0.0
# 2021-10-27  2021-10-27  58482.386719  4.365708e+10         0.0        0.0
# 2021-10-28  2021-10-28  60622.136719  4.525708e+10         0.0        0.0
# 2021-10-29  2021-10-29  62227.964844  3.685688e+10         0.0        0.0
# ...                ...           ...           ...         ...        ...
# 2021-12-22  2021-12-22  48628.511719  2.444798e+10         0.0        0.0
# 2021-12-23  2021-12-23  50784.539062  2.822388e+10         0.0        0.0
# 2021-12-24  2021-12-24  50822.195312  2.436791e+10         0.0        0.0
# 2021-12-25  2021-12-25  50429.859375  1.903065e+10         0.0        0.0
# 2021-12-26  2021-12-26  50809.515625  2.096437e+10         0.0        0.0
#
#             signal_obv  signal_mva  calculated_average ta_query author  ...  \
# date                                                                    ...
# 2021-10-25         2.0         2.0                 1.0      BTC    NaN  ...
# 2021-10-26        -2.0         2.0                 0.2      BTC    NaN  ...
# 2021-10-27        -2.0         2.0                 0.2      BTC    NaN  ...
# 2021-10-28         2.0         2.0                 1.0      BTC    NaN  ...
# 2021-10-29         2.0         2.0                 1.0      BTC    NaN  ...
# ...                ...         ...                 ...      ...    ...  ...
# 2021-12-22        -2.0        -2.0                -1.0      BTC    NaN  ...
# 2021-12-23         2.0        -2.0                -0.2      BTC    NaN  ...
# 2021-12-24         2.0        -2.0                -0.2      BTC    NaN  ...
# 2021-12-25        -2.0        -2.0                -1.0      BTC    NaN  ...
# 2021-12-26         2.0        -2.0                -0.2      BTC    NaN  ...
#
#            publishedAt content source.id source.name Query merge sentiment  \
# date
# 2021-10-25         NaT     NaN       NaN         NaN   NaN   NaN       NaN
# 2021-10-26         NaT     NaN       NaN         NaN   NaN   NaN       NaN
# 2021-10-27         NaT     NaN       NaN         NaN   NaN   NaN       NaN
# 2021-10-28         NaT     NaN       NaN         NaN   NaN   NaN       NaN
# 2021-10-29         NaT     NaN       NaN         NaN   NaN   NaN       NaN
# ...                ...     ...       ...         ...   ...   ...       ...
# 2021-12-22         NaT     NaN       NaN         NaN   NaN   NaN       NaN
# 2021-12-23         NaT     NaN       NaN         NaN   NaN   NaN       NaN
# 2021-12-24         NaT     NaN       NaN         NaN   NaN   NaN       NaN
# 2021-12-25         NaT     NaN       NaN         NaN   NaN   NaN       NaN
# 2021-12-26         NaT     NaN       NaN         NaN   NaN   NaN       NaN
#
#            topic sentiment_bin cluster_strength
# date
# 2021-10-25   NaN           NaN              NaN
# 2021-10-26   NaN           NaN              NaN
# 2021-10-27   NaN           NaN              NaN
# 2021-10-28   NaN           NaN              NaN
# 2021-10-29   NaN           NaN              NaN
# ...          ...           ...              ...
# 2021-12-22   NaN           NaN              NaN
# 2021-12-23   NaN           NaN              NaN
# 2021-12-24   NaN           NaN              NaN
# 2021-12-25   NaN           NaN              NaN
# 2021-12-26   NaN           NaN              NaN
#
# [63 rows x 24 columns]

# %%
# compile the list of dataframes you want to merge
data_frames = [df_ta, news_df, cs_day]

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['date'],
                                            how='outer'), data_frames)

# if you want to fill the values that don't exist in the lines of merged dataframe simply fill with required strings as

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['date'],
                                            how='outer'), data_frames).fillna('void')

# %%
df_merged.reset_index(inplace=True)

# %%
df_merged.set_index('date', inplace=True)

# %%
df_merged = df_merged['2021-11-05':'2021-12-26']

# %%
df_merged
# Out:
#             index         Close       Volume  signal_rsi  signal_bb  \
# date
# 2021-11-05     15  61125.675781  30605102446           0          0
# 2021-11-05     16  61125.675781  30605102446           0          0
# 2021-11-05     17  61125.675781  30605102446           0          0
# 2021-11-05     18  61125.675781  30605102446           0          0
# 2021-11-05     19  61125.675781  30605102446           0          0
# ...           ...           ...          ...         ...        ...
# 2021-12-26   1760  50809.515625  20964372926           0          0
# 2021-12-26   1761  50809.515625  20964372926           0          0
# 2021-12-26   1762  50809.515625  20964372926           0          0
# 2021-12-26   1763  50809.515625  20964372926           0          0
# 2021-12-26   1764  50809.515625  20964372926           0          0
#
#             signal_obv  signal_mva  calculated_average  \
# date
# 2021-11-05          -2           2                 0.2
# 2021-11-05          -2           2                 0.2
# 2021-11-05          -2           2                 0.2
# 2021-11-05          -2           2                 0.2
# 2021-11-05          -2           2                 0.2
# ...                ...         ...                 ...
# 2021-12-26           2          -2                -0.2
# 2021-12-26           2          -2                -0.2
# 2021-12-26           2          -2                -0.2
# 2021-12-26           2          -2                -0.2
# 2021-12-26           2          -2                -0.2
#
#                                                        author  \
# date
# 2021-11-05                                     Richard Lawler
# 2021-11-05   hrobertson@businessinsider.com (Harry Robertson)
# 2021-11-05                                             BeauHD
# 2021-11-05                                               void
# 2021-11-05   hrobertson@businessinsider.com (Harry Robertson)
# ...                                                       ...
# 2021-12-26                                       John Csiszar
# 2021-12-26  newsfeedback@fool.com (Keith Noonan, James Bru...
# 2021-12-26                                        Andrew Lisa
# 2021-12-26                                       John Csiszar
# 2021-12-26                                      deanandreakis
#
#                                                         title  ...  \
# date                                                           ...
# 2021-11-05  A fake press release claiming Kroger accepts c...  ...
# 2021-11-05  JPMorgan says ethereum is a better bet than bi...  ...
# 2021-11-05  Incoming New York Mayor Eric Adams Vows To Tak...  ...
# 2021-11-05  Australia's banking regulator looks into CBA's...  ...
# 2021-11-05  JPMorgan says ethereum is a better bet than bi...  ...
# ...                                                       ...  ...
# 2021-12-26  Shiba Inu and 9 More of the Biggest Hits in Cr...  ...
# 2021-12-26  3 Cryptocurrencies Poised for Monster Rebounds...  ...
# 2021-12-26               Where Does Cryptocurrency Come From?  ...
# 2021-12-26  Shiba Inu and 9 More of the Biggest Hits in Cr...  ...
# 2021-12-26                            Defining the web3 stack  ...
#
#                     publishedAt  \
# date
# 2021-11-05  2021-11-05 13:32:14
# 2021-11-05  2021-11-05 12:06:22
# 2021-11-05  2021-11-05 00:50:00
# 2021-11-05  2021-11-05 08:12:00
# 2021-11-05  2021-11-05 12:06:22
# ...                         ...
# 2021-12-26  2021-12-26 14:01:36
# 2021-12-26  2021-12-26 12:30:00
# 2021-12-26  2021-12-26 14:01:49
# 2021-12-26  2021-12-26 14:01:36
# 2021-12-26  2021-12-26 05:47:01
#
#                                                       content  \
# date
# 2021-11-05  A similar hoax earlier this year tied Walmart ...
# 2021-11-05  Ethereum and bitcoin are the two biggest crypt...
# 2021-11-05  "NYC is going to be the center of the cryptocu...
# 2021-11-05  Representations of the virtual currency Bitcoi...
# 2021-11-05  Ethereum and bitcoin are the two biggest crypt...
# ...                                                       ...
# 2021-12-26  Stanislav Palamar / Getty Images\nBitcoin\nBit...
# 2021-12-26  December has been a tough month for most crypt...
# 2021-12-26  Jirapong Manustrong / iStock.com\nIts fairly c...
# 2021-12-26  Stanislav Palamar / Getty Images\nBitcoin\nBit...
# 2021-12-26  In this next segment of Building on web3, Edge...
#
#                    source.id          source.name         Query  \
# date
# 2021-11-05         the-verge            The Verge       bitcoin
# 2021-11-05  business-insider     Business Insider       bitcoin
# 2021-11-05              void         Slashdot.org       bitcoin
# 2021-11-05           reuters              Reuters       bitcoin
# 2021-11-05  business-insider     Business Insider      ethereum
# ...                      ...                  ...           ...
# 2021-12-26              void  Yahoo Entertainment  shibainucoin
# 2021-12-26              void          Motley Fool     Chainlink
# 2021-12-26              void  Yahoo Entertainment     Chainlink
# 2021-12-26              void  Yahoo Entertainment     Chainlink
# 2021-12-26              void      Edgeandnode.com     Chainlink
#
#                                                         merge sentiment topic  \
# date
# 2021-11-05  A fake press release claiming Kroger accepts c...  Negative  void
# 2021-11-05  JPMorgan says ethereum is a better bet than bi...  Positive  void
# 2021-11-05  Incoming New York Mayor Eric Adams Vows To Tak...  Positive  void
# 2021-11-05  Australia's banking regulator looks into CBA's...   Neutral  void
# 2021-11-05  JPMorgan says ethereum is a better bet than bi...  Positive  void
# ...                                                       ...       ...   ...
# 2021-12-26  Shiba Inu and 9 More of the Biggest Hits in Cr...  Positive  void
# 2021-12-26  3 Cryptocurrencies Poised for Monster Rebounds...  Positive  void
# 2021-12-26  Where Does Cryptocurrency Come From?; It's fai...  Positive  void
# 2021-12-26  Shiba Inu and 9 More of the Biggest Hits in Cr...  Positive  void
# 2021-12-26  Defining the web3 stack; Want to build on web3...   Neutral  void
#
#            sentiment_bin cluster_strength
# date
# 2021-11-05           0.0              0.5
# 2021-11-05           0.0              0.5
# 2021-11-05           0.0              0.5
# 2021-11-05          -1.0              0.5
# 2021-11-05           0.0              0.5
# ...                  ...              ...
# 2021-12-26           0.0              0.5
# 2021-12-26           0.0              0.5
# 2021-12-26           0.0              0.5
# 2021-12-26           0.0              0.5
# 2021-12-26          -1.0              0.5
#
# [1750 rows x 23 columns]

# %%
merged_cols = ['calculated_average', 'sentiment_bin', 'cluster_strength']

# %%
df_final = df_merged[merged_cols]

# %%
df_final
# Out:
#             calculated_average sentiment_bin cluster_strength
# date
# 2021-11-05                 0.2           0.0              0.5
# 2021-11-05                 0.2           0.0              0.5
# 2021-11-05                 0.2           0.0              0.5
# 2021-11-05                 0.2          -1.0              0.5
# 2021-11-05                 0.2           0.0              0.5
# ...                        ...           ...              ...
# 2021-12-26                -0.2           0.0              0.5
# 2021-12-26                -0.2           0.0              0.5
# 2021-12-26                -0.2           0.0              0.5
# 2021-12-26                -0.2           0.0              0.5
# 2021-12-26                -0.2          -1.0              0.5
#
# [1750 rows x 3 columns]

# %% [markdown]
# ## model payoffs

# %% [markdown]
# The mathematical basis for the cascade model provides a logistic function (I). In addition to the current date, news sentiment and indicator scores are summed up and serve as model input. Based on (I) the model calculates the perceived payoffs for strategy A and strategy B. These payoff values function as global parameters for the whole network, implying that every node inside the network perceives the respective payoffs in the same way.
#
#
# A crucial design decision that has been made is that the payoff for strategy B is the counter-calue of the payoff for strategy B. This decision should emphasize that strategy B is simply the absence of strategy A. Therefore, the inequality (II), which decides whether or not a complete strategy A cascade is possible, is reduced to (II.1). In order for a complete strategy A cascade to be hence possible, inside the network on a specific date, there cannot exist a cluster with a cluster strength p greater than a.
#
# - I: equality for payoff a
# - II: inequality for complete cascade p > 1 - b
# - II.1: p > a

# %%
# model_payoffs:

## input:
### x --> linear combination of scores
### date
## output:
### payoff a --> a = 1/(1+exp(-x)), per day
### payoff b --> b = 1 - a, per day

# strategy A --> shock reaction (hype/panic)
# strategy B --> indifferent reaction

# threshold:

## input:
### payoff for strategy a
### payoff for strategy b
## output:
### threshold value q --> q = b / (a + b)

# %% [markdown]
# max cluster strength p has to be greater than a (p>a) for strategy A to cause a complete cascade
#
# - this is because b = 1 - a and q = b/(a+b) (--> a+b = 1 --> q = b/1)
#
# - original threshold formula: p > 1 - q --> p > 1 - b --> p > a (--> b=1-a --> a=1-b)
#
# - so in order for a cluster to break a complete strategy A cascade it has to have a strength greater than a

# %%
df_ta
# Out:
#                  date         Close       Volume  signal_rsi  signal_bb  \
# Date
# 2021-10-21 2021-10-21  62210.171875  45908121370           0          0
# 2021-10-22 2021-10-22  60692.265625  38434082775           0          0
# 2021-10-23 2021-10-23  61393.617188  26882546034           0          0
# 2021-10-24 2021-10-24  60930.835938  27316183882           0          0
# 2021-10-25 2021-10-25  63039.824219  31064911614           0          0
# ...               ...           ...          ...         ...        ...
# 2021-12-27 2021-12-27  50640.417969  24324345758           0          0
# 2021-12-28 2021-12-28  47588.855469  33430376883           0          0
# 2021-12-29 2021-12-29  46444.710938  30049226299           0          0
# 2021-12-30 2021-12-30  47178.125000  26686491018           0          0
# 2021-12-31 2021-12-31  46306.445312  36974172400           0          0
#
#             signal_obv  signal_mva  calculated_average
# Date
# 2021-10-21          -2           2                 0.2
# 2021-10-22          -2           2                 0.2
# 2021-10-23           2           2                 1.0
# 2021-10-24          -2           2                 0.2
# 2021-10-25           2           2                 1.0
# ...                ...         ...                 ...
# 2021-12-27          -2          -2                -1.0
# 2021-12-28          -2          -2                -1.0
# 2021-12-29          -2          -2                -1.0
# 2021-12-30           2          -2                -0.2
# 2021-12-31          -2          -2                -1.0
#
# [72 rows x 8 columns]

# %%
date = df_ta['Date']
date
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# D:\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14168/3796901248.py in <module>
# ----> 1 date = df_ta['Date']
#       2 date
#
# D:\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# D:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Date'

# %%
df = df_final.reset_index().copy()
df
# Out:
#            date  calculated_average sentiment_bin cluster_strength
# 0    2021-11-05                 0.2           0.0              0.5
# 1    2021-11-05                 0.2           0.0              0.5
# 2    2021-11-05                 0.2           0.0              0.5
# 3    2021-11-05                 0.2          -1.0              0.5
# 4    2021-11-05                 0.2           0.0              0.5
# ...         ...                 ...           ...              ...
# 1745 2021-12-26                -0.2           0.0              0.5
# 1746 2021-12-26                -0.2           0.0              0.5
# 1747 2021-12-26                -0.2           0.0              0.5
# 1748 2021-12-26                -0.2           0.0              0.5
# 1749 2021-12-26                -0.2          -1.0              0.5
#
# [1750 rows x 4 columns]

# %%
def calculate_model(df_final):
    df = df_final.reset_index().copy()

    df = df[df.sentiment_bin != 'void']
    df = df[df.cluster_strength != 'void']

    df['calculated_average'] = pd.to_numeric(df['calculated_average'])
    df['sentiment_bin'] = pd.to_numeric(df['sentiment_bin'])
    df['cluster_strength'] = pd.to_numeric(df['cluster_strength'])

    # sum of scores
    df['x'] = df['sentiment_bin'] + df['calculated_average']

    # payoffs
    df['a'] = 0

    for index, row in df.iterrows():
        df.loc[index, 'a'] = 1 / (1 + math.exp( -(df.loc[index, 'x'])))

    df['b'] = 1 - df['a']

    # threshold
    df['q'] = df['b'] / (df['a'] + df['b'])

    df['1-q'] = 1 - df['q']

    df_result = df[['date', 'a', 'cluster_strength']].set_index('date')
    
    return df_result

# %%
plt.figure(figsize = (15,8))

#ax = sns.lineplot(data=df, x='date', y="1-q")
#ax = sns.lineplot(data=df, x='date', y="q")
ax = sns.lineplot(data=df_result)

# specify the position of the major ticks at the beginning of the week
ax.xaxis.set_major_locator(md.WeekdayLocator(byweekday = 2))

# specify the format of the labels as 'year-month-day'
ax.xaxis.set_major_formatter(md.DateFormatter('%Y-%m-%d'))

# (optional) rotate by 90° the labels in order to improve their spacing
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 90)

# specify the position of the minor ticks at each day
ax.xaxis.set_minor_locator(md.DayLocator(interval = 1))

ax.tick_params(axis = 'x', which = 'major', length = 10)
ax.tick_params(axis = 'x', which = 'minor', length = 5)

#ax.set_title('1-q / Treshold')

plt.show()

# %%
df = df[df.sentiment_bin != 'void']
df = df[df.cluster_strength != 'void']

# %%
df['calculated_average'] = pd.to_numeric(df['calculated_average'])
df['sentiment_bin'] = pd.to_numeric(df['sentiment_bin'])
df['cluster_strength'] = pd.to_numeric(df['cluster_strength'])

# %%
# sum of scores
df['x'] = df['sentiment_bin'] + df['calculated_average']

# %%
# import math


# # date = df_ta['date']
# # n = -1
# # t = -1

# def cascade_model(date, news, ta):
    
#     #sum of scores
#     x = news + ta
    
#     #payoffs
#     a = 1 / (1 + math.exp(-x))
#     b = 1 - a
    
#     #threshold
#     q = b / (a + b)
    
#     #output
#     model_output_dict = {}
    
#     for d in date:
#         model_output_dict[d] = [(a,b), 1 - q]
                                
#     return model_output_dict

# cascade_model(date=df['date'], news=df['sentiment_bin'], ta=df['calculated_average'])

# %%
#payoffs
df['a'] = 0

for index, row in df.iterrows():
    df.loc[index, 'a'] = 1 / (1 + math.exp( -(df.loc[index, 'x'])))

df['b'] = 1 - df['a']

# %%
#threshold
df['q'] = df['b'] / (df['a'] + df['b'])

df['1-q'] = 1 - df['q']

# %%
df
# Out:
#            date  calculated_average  sentiment_bin  cluster_strength    x  \
# 0    2021-11-05                 0.2            0.0               0.5  0.2
# 1    2021-11-05                 0.2            0.0               0.5  0.2
# 2    2021-11-05                 0.2            0.0               0.5  0.2
# 3    2021-11-05                 0.2           -1.0               0.5 -0.8
# 4    2021-11-05                 0.2            0.0               0.5  0.2
# ...         ...                 ...            ...               ...  ...
# 1745 2021-12-26                -0.2            0.0               0.5 -0.2
# 1746 2021-12-26                -0.2            0.0               0.5 -0.2
# 1747 2021-12-26                -0.2            0.0               0.5 -0.2
# 1748 2021-12-26                -0.2            0.0               0.5 -0.2
# 1749 2021-12-26                -0.2           -1.0               0.5 -1.2
#
#              a         b         q       1-q
# 0     0.549834  0.450166  0.450166  0.549834
# 1     0.549834  0.450166  0.450166  0.549834
# 2     0.549834  0.450166  0.450166  0.549834
# 3     0.310026  0.689974  0.689974  0.310026
# 4     0.549834  0.450166  0.450166  0.549834
# ...        ...       ...       ...       ...
# 1745  0.450166  0.549834  0.549834  0.450166
# 1746  0.450166  0.549834  0.549834  0.450166
# 1747  0.450166  0.549834  0.549834  0.450166
# 1748  0.450166  0.549834  0.549834  0.450166
# 1749  0.231475  0.768525  0.768525  0.231475
#
# [1665 rows x 9 columns]

# %%
sns.displot(df['q'])
sns.displot(df['1-q']);

# %%
df
# Out:
#            date  calculated_average  sentiment_bin  cluster_strength    x  \
# 0    2021-11-05                 0.2            0.0               0.5  0.2
# 1    2021-11-05                 0.2            0.0               0.5  0.2
# 2    2021-11-05                 0.2            0.0               0.5  0.2
# 3    2021-11-05                 0.2           -1.0               0.5 -0.8
# 4    2021-11-05                 0.2            0.0               0.5  0.2
# ...         ...                 ...            ...               ...  ...
# 1745 2021-12-26                -0.2            0.0               0.5 -0.2
# 1746 2021-12-26                -0.2            0.0               0.5 -0.2
# 1747 2021-12-26                -0.2            0.0               0.5 -0.2
# 1748 2021-12-26                -0.2            0.0               0.5 -0.2
# 1749 2021-12-26                -0.2           -1.0               0.5 -1.2
#
#              a         b         q       1-q
# 0     0.549834  0.450166  0.450166  0.549834
# 1     0.549834  0.450166  0.450166  0.549834
# 2     0.549834  0.450166  0.450166  0.549834
# 3     0.310026  0.689974  0.689974  0.310026
# 4     0.549834  0.450166  0.450166  0.549834
# ...        ...       ...       ...       ...
# 1745  0.450166  0.549834  0.549834  0.450166
# 1746  0.450166  0.549834  0.549834  0.450166
# 1747  0.450166  0.549834  0.549834  0.450166
# 1748  0.450166  0.549834  0.549834  0.450166
# 1749  0.231475  0.768525  0.768525  0.231475
#
# [1665 rows x 9 columns]

# %%
df_result = df[['date', 'a', 'cluster_strength']].set_index('date')

# %%
plt.figure(figsize = (15,8))

#ax = sns.lineplot(data=df, x='date', y="1-q")
#ax = sns.lineplot(data=df, x='date', y="q")
ax = sns.lineplot(data=df_result)

# specify the position of the major ticks at the beginning of the week
ax.xaxis.set_major_locator(md.WeekdayLocator(byweekday = 2))

# specify the format of the labels as 'year-month-day'
ax.xaxis.set_major_formatter(md.DateFormatter('%Y-%m-%d'))

# (optional) rotate by 90° the labels in order to improve their spacing
plt.setp(ax.xaxis.get_majorticklabels(), rotation = 90)

# specify the position of the minor ticks at each day
ax.xaxis.set_minor_locator(md.DayLocator(interval = 1))

ax.tick_params(axis = 'x', which = 'major', length = 10)
ax.tick_params(axis = 'x', which = 'minor', length = 5)

#ax.set_title('1-q / Treshold')

plt.show()

# %%
df_ta['Close'].plot(legend=True,figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Date'>
